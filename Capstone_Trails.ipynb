# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ###### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import requests 
import bs4
import folium
import json
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import time

# %% [markdown]
# ###### Get Data from Wiki

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
if response.status_code == 200: 
    print ("Get Successful!")
else:
    print ("Get Failed! Check URL")
# Out:
# Get Successful!

# %% [markdown]
# ###### Payload Received From Wiki

# %%
# print(response.text) # Commented out to avoid filling the notebook with the response text

# %% [markdown]
# ###### Parse the response text using BeautifulSoap

# %%
resp_soap = bs4.BeautifulSoup(response.text, 'html.parser')
resp_soap.title
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %% [markdown]
# ### Assumptions
#  * Postal Code & Borough combination is expected have same value for all the nieighbourhoods with those combinations.
#  * **_check_\__for_\__discrepancy_** is used to shout if there are any discrepancies found while processing the rows.

# %%
def check_for_discrepancy(pos_dict,row_list):
    
    if row_list[0] in pos_dict and pos_dict[row_list[0]][0] != row_list[1]:
        print ("Warning! Existing Postal Codes and Borough combination is differeing from the new row")
        print (f"Existing Postal Code {row_list[0]} Borough {pos_dict[row_list[0]][0]}")
        print (f"New Postal Code {row_list[0]} Borough {row_list[1]}")

# %% [markdown]
# ### Approach
# * Very first table from the Response Text will be parsed to get all the Postal Codes
# * **_get_\__list_\__of_\__postal_\__codes_** will parse all the rows.
# * **_get_\__row_\__list_** will parse the columns.
# * Postal Code Dictionary (_with postal code as a Key_) is maintained to store all the parsed postal codes.
# * If Borough i.e. Column #2 is "Not Assigned", it will skip adding the rows to the Postal Code Dictionary
# * If Nieighbourhood i.e. Column #3 is "Not Assigned" but if the Borough is valid, it will assign the Borough as its neighbourhood before adding the row to the Dictionary.
# * List is maintained to keep track of the Neighbourhoods that are having same postal code
# * Another List is maintained to keep track of the rows that are having valid Borough but "Not assigned" Neighbourhood

# %%
def add_to_dictionary(pos_dict,row_list,more_nbh):
    
    if (row_list[0]) in pos_dict:
        more_nbh.append(row_list[0])
        pos_dict[row_list[0]][1] = pos_dict[row_list[0]][1] + ", " + row_list[2]
    else:
        pos_dict[row_list[0]] = [row_list[1],row_list[2]]

# %%
def get_row_list(row):
    
    row_list = []    
    for column in row:
        
        if isinstance(column,bs4.element.Tag): # Avoid processing NavigableString - Mostly newline char            
            row_list.append(column.get_text(strip=True))
            
    return row_list

# %%
def get_list_of_postal_codes(soap_msg_table):
    
    pos_dict = {}
    more_nbh = []
    na_nbh = []
    for row in soap_msg_table:
        
        if isinstance(row,bs4.element.Tag): # Avoid processing NavigableString - Mostly newline char
            row_list = get_row_list(row)
            
            if row_list[1].replace(' ','').lower() != 'notassigned' and row_list[2].replace(' ','').lower() == 'notassigned':
                na_nbh.append(row_list[0])
                row_list[2] = row_list[1]
                add_to_dictionary(pos_dict,row_list,more_nbh)
                
            elif row_list[1].replace(' ','').lower() != 'notassigned':                
                add_to_dictionary(pos_dict,row_list,more_nbh)
            
            # Check for discrepancy
            check_for_discrepancy(pos_dict,row_list)
            
    return pos_dict,more_nbh,na_nbh

# %% [markdown]
# ###### Extracting & Parsing the very first table from the response text

# %%
resp_table = resp_soap.table
postal_code_list, more_nbh, na_nbh = get_list_of_postal_codes(resp_table.tbody)

# %% [markdown]
# ###### Creating a DataFrame from the Parsed Dictionary.
# * _orient_ is used to parse the keys as Index
# * Removing the first row as it is a header from the table
# * Resetting the Index to get the DataFrame in an expected way.
# * Adding the expected column names to the DataFrame

# %%
pos_df = pd.DataFrame.from_dict(postal_code_list,orient='index')
pos_df = pos_df[1:]
pos_df = pos_df.reset_index()
pos_df.columns = ['PostalCode','Borough','Neighborhood']

# %% [markdown]
# ###### Postal Code with more than one neightbourhood - Eg : M5A is used

# %%
pos_df.loc[pos_df['PostalCode'] == 'M5A']['Neighborhood'].values
# Out:
# array(['Harbourfront, Regent Park'], dtype=object)

# %% [markdown]
# ###### All Postal Codes that are having more than one neightbourhood

# %%
pos_df.loc[pos_df['PostalCode'].isin(set(more_nbh))]
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 6          M1B       Scarborough
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 28         M3H        North York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 33         M2J        North York
# 34         M3J        North York
# 36         M5J  Downtown Toronto
# 37         M6J      West Toronto
# 38         M1K       Scarborough
# 40         M3K        North York
# 41         M4K      East Toronto
# 42         M5K  Downtown Toronto
# 43         M6K      West Toronto
# 44         M1L       Scarborough
# 45         M2L        North York
# 47         M4L      East Toronto
# 48         M5L  Downtown Toronto
# 49         M6L        North York
# 51         M1M       Scarborough
# 52         M2M        North York
# 55         M5M        North York
# 56         M6M              York
# 57         M9M        North York
# 58         M1N       Scarborough
# 63         M6N              York
# 65         M1P       Scarborough
# 68         M5P   Central Toronto
# 69         M6P      West Toronto
# 71         M1R       Scarborough
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 77         M9R         Etobicoke
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 93         M8W         Etobicoke
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 6                                       Rouge, Malvern
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 30                            Adelaide, King, Richmond
# 31                        Dovercourt Village, Dufferin
# 33                        Fairview, Henry Farm, Oriole
# 34                     Northwood Park, York University
# 36   Harbourfront East, Toronto Islands, Union Station
# 37                            Little Portugal, Trinity
# 38         East Birchmount Park, Ionview, Kennedy Park
# 40                         CFB Toronto, Downsview East
# 41                        The Danforth West, Riverdale
# 42            Design Exchange, Toronto Dominion Centre
# 43        Brockton, Exhibition Place, Parkdale Village
# 44                     Clairlea, Golden Mile, Oakridge
# 45                            Silver Hills, York Mills
# 47                      The Beaches West, India Bazaar
# 48                      Commerce Court, Victoria Hotel
# 49                  Downsview, North Park, Upwood Park
# 51     Cliffcrest, Cliffside, Scarborough Village West
# 52                             Newtonbrook, Willowdale
# 55                   Bedford Park, Lawrence Manor East
# 56      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 57                                    Emery, Humberlea
# 58                         Birch Cliff, Cliffside West
# 63                       The Junction North, Runnymede
# 65   Dorset Park, Scarborough Town Centre, Wexford ...
# 68                 Forest Hill North, Forest Hill West
# 69                       High Park, The Junction South
# 71                                   Maryvale, Wexford
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 93                              Alderwood, Long Branch
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...

# %% [markdown]
# ###### Postal Codes that were having "Not assigned" neighbourhood

# %%
pos_df.loc[pos_df['PostalCode'].isin(set(na_nbh))]
# Out:
#   PostalCode       Borough  Neighborhood
# 4        M7A  Queen's Park  Queen's Park

# %% [markdown]
# ###### Resultant DataFrame - Only first 10 rows are displayed

# %%
pos_df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park
# 3        M6A        North York  Lawrence Heights, Lawrence Manor
# 4        M7A      Queen's Park                      Queen's Park
# 5        M9A         Etobicoke                  Islington Avenue
# 6        M1B       Scarborough                    Rouge, Malvern
# 7        M3B        North York                   Don Mills North
# 8        M4B         East York   Woodbine Gardens, Parkview Hill
# 9        M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# ###### Shape of the Resultant Dataframe

# %%
print(f"{pos_df.shape}")
# Out:
# (103, 3)

# %% [markdown]
# ## Extracting & Merging Geospatial Data

# %% [markdown]
# <font color=red>**Note:**</font> I don't seem to be recieveing data that are consistent with the Geospatial Data Provided in the Assignment Section. So, i will be using the data file provided in the Assignment Section

# %%
# !wget -q http://cocl.us/Geospatial_data

# %% [markdown]
# ###### Read the data file into a DataFrame & Rename the columns to match the existing DataFrame

# %%
geo_data = pd.read_csv('Geospatial_data',header=0)
geo_data.columns = ['PostalCode','Latitude','Longitude']

# %%
geo_data.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# ###### Make sure all the postal codes are having the corresponding Latitude & Longitude values from Geospatial_data

# %%
pos_df.loc[~pos_df['PostalCode'].isin(geo_data['PostalCode'])].size
# Out:
# 0

# %% [markdown]
# ###### Merge the DataFrames based on Postal Codes

# %%
mgd_pos_df = pos_df.merge(right=geo_data,on='PostalCode')
mgd_pos_df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
# 5        M9A         Etobicoke                  Islington Avenue  43.667856
# 6        M1B       Scarborough                    Rouge, Malvern  43.806686
# 7        M3B        North York                   Don Mills North  43.745906
# 8        M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9        M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ###### Shape of the Merged Dataframe

# %%
print(f"{mgd_pos_df.shape}")
# Out:
# (103, 5)

# %% [markdown]
# ## Clustering the neighbourhoods

# %%
print (f"There are {mgd_pos_df['Borough'].unique().size} unique Borough's from the merged DataFrame")
# Out:
# There are 11 unique Borough's from the merged DataFrame

# %% [markdown]
# ### Approach
# * **Only Borough's that contains the word "Toronto" will be analyzed below**.
# * https://nominatim.openstreetmap.org/ will be queried directly to get the Geocodes
# * foursquare api will be used to analyze the neighbourhoods.

# %% [markdown]
# ###### Get Geo codes for a specific location.

# %%
def get_geo_codes(area):
    longitude = ""
    latitude = ""
    try:
        # Replace the space with +
        area_str = area.replace(" ","+")
        
        # Get the Geolocation for given area
        response = requests.get('https://nominatim.openstreetmap.org/search?q='+area_str+'&format=geojson&limit=1')
        if response.status_code == 200:
            print ("Get Successful")
            
            # Extract the Latitude & Longitude from the response text
            longitude,latitude = json.loads(response.text)['features'][0]['geometry']['coordinates']
            print(f"latitude & longitude values of {area} are {latitude},{longitude}")
        else:
            print ("Get Failed!")
    except:
        pass
    
    return latitude,longitude

# %% [markdown]
# ###### Extract Latitude & Longitude for Toronto,ON

# %%
latitude,longitude = get_geo_codes('Toronto ON')
# Out:
# Get Successful
# latitude & longitude values of Toronto ON are 43.653963,-79.387207

# %% [markdown]
# #### Create a map of Toronto with neighborhoods superimposed on top.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(mgd_pos_df['Latitude'], mgd_pos_df['Longitude'], mgd_pos_df['Borough'], mgd_pos_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='green').add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Create a dataframe with Boroughs that has a word "Toronto" Note : Only this dataframe toronto_df will be analyzed futher.

# %%
toronto_df = mgd_pos_df
toronto_df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
toronto_df.shape
# Out:
# (103, 5)

# %% [markdown]
# ###### Set the Credentials for Foursquare API

# %%
CLIENT_ID = 'KGU5MEU4ZHYXQPJT2Y1B2DNRFFTV1GSD4Y5KXV0WMSFFDLQO' # your Foursquare ID
CLIENT_SECRET = 'S30A30GKJ1SITKL3YOTXQAPTCJBYQGUMONMF4H4CNVJTAVOT' # your Foursquare Secret
VERSION = '20190531' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KGU5MEU4ZHYXQPJT2Y1B2DNRFFTV1GSD4Y5KXV0WMSFFDLQO
# CLIENT_SECRET:S30A30GKJ1SITKL3YOTXQAPTCJBYQGUMONMF4H4CNVJTAVOT

# %% [markdown]
# ###### Get Nearby Venues from each Neighbourhood
# * radius is set to 2000 to have enough datapoints for each neighbourhood
# * LIMIT is set to 100 for all the neighbourhoods. However, there may be some cases with less number of records recived from the API

# %%
def getVenueLikes(id):
    
    url = 'https://api.foursquare.com/v2/venues/{}/likes?&client_id={}&client_secret={}&v={}'.format(
            id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # make the GET request
    results = requests.get(url).json()["response"]['likes']

    return results['count']

# %%
getVenueLikes('4bd6e35d637ba5933ad3f870')
# Out:
# 62

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=10000):
    
    LIMIT = 500
    # Athletics & Sports {4f4528bc4b90abdf24c9de85}, Pool {4bf58dd8d48988d15e941735},
    
    CATEGORY = '4f4528bc4b90abdf24c9de85,4bf58dd8d48988d15e941735'
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            CATEGORY)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['id'],
            v['venue']['name'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['location']['distance'], 
            v['venue']['categories'][0]['name']) for v in results])
        
        #print (venues_list)
        #for v in venues_list:
        #    print ("v",v)
        #    for v1 in v:
        #        print ("v1", v1)
       #         count,summary = getVenueLikes(v1[3])
       #        v.append(count)
        #        v.append(summary)
            
        #break
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude',
                  'Venue Id',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue Distance', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ###### Get Venues from each Neighbourhood

# %%
#toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
#                                   latitudes=toronto_df['Latitude'],
#                                   longitudes=toronto_df['Longitude']
#                                  )
#csv_export = toronto_venues.to_csv (r'toronto_dataframe.csv', index = None, header=True)
toronto_venues = pd.read_csv('toronto_dataframe.csv',header=0)
toronto_venues.head()

# %%
pd.DataFrame(toronto_venues.groupby('Venue Category').count()['Venue'])
# Out:
#                                           Venue
# Venue Category
# Arcade                                       24
# Athletics & Sports                          864
# Badminton Court                              58
# Baseball Field                              212
# Basketball Court                             54
# Boxing Gym                                    1
# Building                                     57
# Climbing Gym                                125
# College Gym                                 168
# College Rec Center                           44
# College Stadium                              12
# Community Center                             68
# Curling Ice                                  34
# Cycle Studio                                 12
# Elementary School                            54
# Event Space                                  35
# Field                                         7
# Golf Course                                 384
# Gym                                        3470
# Gym / Fitness Center                       1849
# Gym Pool                                     29
# High School                                   4
# Hockey Arena                                 24
# Hockey Field                                  4
# Hotel                                        11
# Hotel Pool                                    1
# Martial Arts Dojo                           110
# Office                                      118
# Other Great Outdoors                          6
# Paintball Field                              10
# Park                                        331
# Physical Therapist                            2
# Pilates Studio                                2
# Playground                                   24
# Plaza                                        55
# Pool                                        421
# Recreation Center                             2
# Residential Building (Apartment / Condo)     22
# School                                        1
# Skate Park                                    2
# Skating Rink                                231
# Soccer Field                                210
# Soccer Stadium                               57
# Social Club                                   8
# Sports Club                                  78
# Stadium                                      52
# Swim School                                   8
# Tennis Court                                 98
# Track                                        19
# Trail                                        50
# Water Park                                    2
# Weight Loss Center                            2
# Yoga Studio                                 551

# %%
toronto_venues['Venue Likes'].unique()
# Out:
# array([ 28,  11,  34,  15,  51,   7,  29,  43,  12,   3,  10,  33,   8,
#         39,  38,  21,  14,  62,  54,  18,  25,   1,   6,  32,  19,   5,
#          0,  16,  31,   2,   4,  17,  27,  22,  30,  45,  20, 126,  78,
#         64,  60,   9,  23,  36, 672, 181,  57,  53,  41,  55,  86,  70,
#        148,  26,  76,  42,  13,  47,  24,  73,  37,  68])

# %%
toronto_venues.sort_values(by=['Venue Category'],ascending=False)
# Out:
#                                            Neighborhood  \
# 6891                                          Westmount
# 7320                The Annex, North Midtown, Yorkville
# 2353                                 Central Bay Street
# 7426                             Parkdale, Roncesvalles
# 7423                             Parkdale, Roncesvalles
# 7419                             Parkdale, Roncesvalles
# 7417                             Parkdale, Roncesvalles
# 7416                             Parkdale, Roncesvalles
# 7412                             Parkdale, Roncesvalles
# 3322                    Northwood Park, York University
# 2364                                 Central Bay Street
# 7392                             Parkdale, Roncesvalles
# 7356                             Parkdale, Roncesvalles
# 1058                                          Glencairn
# 7353                             Parkdale, Roncesvalles
# 3315                    Northwood Park, York University
# 1060                                          Glencairn
# 7465              Canada Post Gateway Processing Centre
# 7466              Canada Post Gateway Processing Centre
# 2350                                 Central Bay Street
# 2265                                            Leaside
# 1039                                          Glencairn
# 2256                                            Leaside
# 3365                    Northwood Park, York University
# 7574  Kingsview Village, Martin Grove Gardens, Richv...
# 7567  Kingsview Village, Martin Grove Gardens, Richv...
# 3364                    Northwood Park, York University
# 5035    Cliffcrest, Cliffside, Scarborough Village West
# 2349                                 Central Bay Street
# 2296                                 Central Bay Street
# ...                                                 ...
# 2372                                           Christie
# 7562  Kingsview Village, Martin Grove Gardens, Richv...
# 2374                                           Christie
# 7538  Kingsview Village, Martin Grove Gardens, Richv...
# 7558  Kingsview Village, Martin Grove Gardens, Richv...
# 9213                                          Northwest
# 7019                                  Maryvale, Wexford
# 4355                    Clairlea, Golden Mile, Oakridge
# 3309                    Northwood Park, York University
# 1707  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 747                                     Don Mills North
# 3739        East Birchmount Park, Ionview, Kennedy Park
# 6536                                    York Mills West
# 1324                   Flemingdon Park, Don Mills South
# 3267                       Fairview, Henry Farm, Oriole
# 3959                        CFB Toronto, Downsview East
# 5149                            Newtonbrook, Willowdale
# 4457                           Silver Hills, York Mills
# 5889                                Downsview Northwest
# 81                                            Parkwoods
# 9187                             Alderwood, Long Branch
# 5026    Cliffcrest, Cliffside, Scarborough Village West
# 8127            Clarks Corners, Sullivan, Tam O'Shanter
# 2752    Bathurst Manor, Downsview North, Wilson Heights
# 4896                                      Humber Summit
# 195                                    Victoria Village
# 7503              Canada Post Gateway Processing Centre
# 6425  Dorset Park, Scarborough Town Centre, Wexford ...
# 5737                        Birch Cliff, Cliffside West
# 7086                                    Willowdale West
#
#       Neighborhood Latitude  Neighborhood Longitude                  Venue Id  \
# 6891              43.696319              -79.532242  4cbb1b07035d236a7420de4e
# 7320              43.672710              -79.405678  4cbb1b07035d236a7420de4e
# 2353              43.657952              -79.387383  50bf6e53d86ce1965377956b
# 7426              43.648960              -79.456325  4efa4c786c25c411edcaf286
# 7423              43.648960              -79.456325  4aeb5989f964a5203ec121e3
# 7419              43.648960              -79.456325  4cbb1b07035d236a7420de4e
# 7417              43.648960              -79.456325  50bf6e53d86ce1965377956b
# 7416              43.648960              -79.456325  4e38175dd4c0dc7ad2ec326a
# 7412              43.648960              -79.456325  4d90ca3cc1b1721e93666346
# 3322              43.767980              -79.487262  4b68b3dcf964a52009882be3
#       Venue Longitude  Venue Distance      Venue Category
# 6891       -79.427108            9717         Yoga Studio
# 7320       -79.427108            2753         Yoga Studio
# 2353       -79.389158            2166         Yoga Studio
# 7426       -79.397472            8069         Yoga Studio
# 7423       -79.383636            6018         Yoga Studio
# 7419       -79.427108            2405         Yoga Studio
# 7417       -79.389158            5533         Yoga Studio
# 7416       -79.520312            5335         Yoga Studio
# 7412       -79.396086            4853         Yoga Studio
# 3322       -79.405468            6596         Yoga Studio
# 2364       -79.397472            5590         Yoga Studio
# 7392       -79.388485            6155         Yoga Studio
# 7356       -79.403185            4343         Yoga Studio
# 1058       -79.389158            9100         Yoga Studio
# 7353       -79.420133            2919         Yoga Studio
# 3315       -79.397472            9862         Yoga Studio
# 1060       -79.427108            6414         Yoga Studio
# 7465       -79.649665            6026         Yoga Studio
# 7466       -79.520312            7694         Yoga Studio
# 2350       -79.396086            1320         Yoga Studio
# 2265       -79.389158            8119         Yoga Studio
# 1039       -79.397472            3836         Yoga Studio
# 2256       -79.383636            5538         Yoga Studio
# 3365       -79.388737            7921         Yoga Studio
# 7574       -79.468441            7408         Yoga Studio
# 7567       -79.520312            6449         Yoga Studio
# 3364       -79.507183            7667         Yoga Studio
# 5035       -79.324335            8916         Yoga Studio
# 2349       -79.383636             496         Yoga Studio
# 2296       -79.403185            2153         Yoga Studio
# ...               ...             ...                 ...
# 2372       -79.351306            6259  Athletics & Sports
# 7562       -79.519706            8998  Athletics & Sports
# 2374       -79.396002            3510  Athletics & Sports
# 7538       -79.480454            8712  Athletics & Sports
# 7558       -79.461677            8105  Athletics & Sports
# 9213       -79.682865            7222  Athletics & Sports
# 7019       -79.357463            6897              Arcade
# 4355       -79.357463            5882              Arcade
# 3309       -79.526890            7788              Arcade
# 1707       -79.653555            9847              Arcade
# 747        -79.357463            4353              Arcade
# 3739       -79.357463            8024              Arcade
# 6536       -79.357463            6140              Arcade
# 1324       -79.357463            2491              Arcade
# 3267       -79.357463            8011              Arcade
# 3959       -79.357463            9275              Arcade
# 5149       -79.357463           10015              Arcade
# 4457       -79.357463            5791              Arcade
# 5889       -79.526890            7828              Arcade
# 81         -79.357463            5616              Arcade
# 9187       -79.653555            9404              Arcade
# 5026       -79.357463            9550              Arcade
# 8127       -79.357463            9345              Arcade
# 2752       -79.357463            8619              Arcade
# 4896       -79.526890            8974              Arcade
# 195        -79.357463            3973              Arcade
# 7503       -79.653555            7594              Arcade
# 6425       -79.357463            8794              Arcade
# 5737       -79.357463            7622              Arcade
# 7086       -79.526890            8723              Arcade
#
# [10077 rows x 10 columns]

# %%
def identify_the_closest_nh(df):
    return df.sort_values(by=['Venue Distance'],ascending=True).iloc[0]

# %%
def venues_eliminate_duplicates(df):
    venue_list = df['Venue'].unique()
    print(venue_list.size)
    unique_venues = pd.DataFrame(columns=['Neighborhood','Neighborhood Latitude','Neighborhood Longitude','Venue Id','Venue','Venue Latitude','Venue Longitude','Venue Distance','Venue Category'])
    for venue in venue_list:
        print (venue)
# 1267                 Dennis R. Timbrell Resource Centre       43.718096
# ...                                                 ...             ...
# 8375                                   Angus Glen Arena       43.894571
# 9342                   My Gym Children's Fitness Center       43.901010
# 9347                                Markham Soccer Club       43.895036
# 8424                           Within Range Golf Centre       43.834112
# 8428                           Angus Glen Tennis Centre       43.894899
# 8429                     York Downs Golf & Country Club       43.885894
# 8430                    Lee's Badminton Training Centre       43.853067
# 8632                                       Panorama Gym       43.637953
# 8673                               Oasis Fitness Centre       43.636806
# 8716                             Neptune Fitness Centre       43.636686
# 8717                                       Bang Fitness       43.647039
# 8720                        The Matrix Gym (City Place)       43.642913
# 9213                                     Battle Archery       43.716157
# 9215                      Earnscliffe Recreation Centre       43.723674
# 8749                                  Peel Archery Club       43.722626
# 8775             GoodLife Fitness Brampton Woodhill Gym       43.747506
# 9172                                    The Motion Room       43.665434
# 9206                     Colonel Samuel Smith Ice Trail       43.593327
# 9257                                  Rogers Campus Gym       43.703808
# 9288                                      Lambton Arena       43.664771
# 9290                            Varsity Training Centre       43.680045
# 9333                                   CrossFit Markham       43.906236
# 9351                         Mount Joy Community Centre       43.892127
# 9357                                    Centennial park       43.872115
# 9359             Cornerstone Christian Community Church       43.907324
# 9362                                        Legacy Park       43.863084
# 9370                        Centennial Community Centre       43.872969
# 9373                                    Mount Joy Arena       43.893364
# 9375           Crosby Memorial Community Centre & Arena       43.868742
# 9376                            Unionville Curling Club       43.868946
#
#       Venue Longitude Venue Distance        Venue Category
# 4570       -79.324038           1225    Athletics & Sports
# 8910       -79.388559            896    Athletics & Sports
# 2570       -79.344064           1900                   Gym
# 5356       -79.418732            714           Sports Club
# 676        -79.347077            455  Gym / Fitness Center
# 5755       -79.414982            607                  Pool
# 104        -79.323714           1419  Gym / Fitness Center
# 5965       -79.381986            782  Gym / Fitness Center
# 780        -79.309279            476  Gym / Fitness Center
# 6461       -79.406346           1039                   Gym
# 3177       -79.328195           1606  Gym / Fitness Center
# 11         -79.341707           3029                   Gym
# 8337       -79.301411           1672                   Gym
# 7746       -79.387274            705                   Gym
# 8254       -79.402964            695  Gym / Fitness Center
# 6953       -79.313351           1655                   Gym
# 5267       -79.342794            723          Climbing Gym
# 2089       -79.228533           1693                   Gym
# 6571       -79.395981            696                   Gym
# 3276       -79.474256           1599  Gym / Fitness Center
# 5762       -79.411936            644                   Gym
# 7639       -79.255324           1198  Gym / Fitness Center
# 6366       -79.274962            622  Gym / Fitness Center
# 3073       -79.213702           2084                   Gym
# 7642       -79.262510           1791                   Gym
# 8958       -79.389857           3262                   Gym
# 1262       -79.338759           1490    Athletics & Sports
# 5663       -79.257952            883                   Gym
# 804        -79.313411            485    Athletics & Sports
# 1267       -79.331728           1141  Gym / Fitness Center
# ...               ...            ...                   ...
# 8375       -79.336175           9752    Athletics & Sports
# 9342       -79.264609           8635            Playground
# 9347       -79.261787           7957          Soccer Field
# 8424       -79.374838           7546           Golf Course
# 8428       -79.337807           9842          Tennis Court
# 8429       -79.327584           8588           Golf Course
# 8430       -79.363891           7634       Badminton Court
# 8632       -79.397996           1043                   Gym
# 8673       -79.405725           8448                   Gym
# 8716       -79.404664           8521                   Gym
# 8717       -79.404885           9034                   Gym
# 8720       -79.392462           9703                   Gym
# 9213       -79.682865           7222    Athletics & Sports
# 9215       -79.699496           8690     Recreation Center
# 8749       -79.688210           8240    Athletics & Sports
# 8775       -79.699878           9007                   Gym
# 9172       -79.485634           8422  Gym / Fitness Center
# 9206       -79.515506           2471          Skating Rink
# 9257       -79.714913           9731                   Gym
# 9288       -79.505995           8490          Skating Rink
# 9290       -79.705024           9413          Skating Rink
# 9333       -79.265927           9182  Gym / Fitness Center
# 9351       -79.257636           7502           Event Space
# 9357       -79.289501           7834                  Park
# 9359       -79.243383           8484           Sports Club
# 9362       -79.235541           3843        Baseball Field
# 9370       -79.287282           7731      Community Center
# 9373       -79.282153           8849          Hockey Arena
# 9375       -79.312684           9328          Skating Rink
# 9376       -79.313210           9376           Curling Ice
#
# [611 rows x 9 columns]

# %%
def get_attr_value(resp_dict,attribute):
    
    if attribute in resp_dict:
        return resp_dict[attribute]
    
    return ''

# %%
def has_attr(resp_dict,attribute):
    
    return attribute in resp_dict

# %%
def get_reasons_items(reasons_items):
    
    risummary = get_attr_value(reasons_items,'summary')
    ritype = get_attr_value(reasons_items,'type')
    rireasonName = get_attr_value(reasons_items,'reasonName')
    
    return (risummary,ritype,rireasonName)

# %%
def get_reasons(curr_resp_dict,reasons):
    
    curr_resp_dict['reasons_count'] = get_attr_value(reasons,'count')
    
    items = ()
    index = 1
    for item in reasons['items']:
        items = get_reasons_items(item)
        curr_resp_dict[f'reasons_item_summary_{index}'] = items[0]
        curr_resp_dict[f'reasons_item_type_{index}'] = items[1]
        curr_resp_dict[f'reasons_item_reasonname_{index}'] = items[2]
        break

# %%
def getVenueDetails(id):
    
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # make the GET request
    #response_msg = requests.get(url).json()["response"]['venue']
    
    curr_resp_list = []
    curr_resp_dict = {'venue_id':id,'verified':'','tip_count':'',
                'likes':'','rating':'','ratingSignals':'','reasons_count':'',
                'reasons_item_summary_1':''}
    
    curr_resp_dict['verified'] = get_attr_value(response_msg,'verified')
    
    if has_attr(response_msg,'stats'):
        curr_resp_dict['tip_count'] = get_attr_value(response_msg['stats'],'tipCount')
        
    if has_attr(response_msg,'likes'):
        curr_resp_dict['likes'] = get_attr_value(response_msg['likes'],'count')
    
    curr_resp_dict['rating'] = get_attr_value(response_msg,'rating')
    curr_resp_dict['ratingSignals'] = get_attr_value(response_msg,'ratingSignals')
    
    if has_attr(response_msg,'reasons'):
        get_reasons(curr_resp_dict,response_msg['reasons'])
    
    return curr_resp_dict

# %%
def getDetailsforallVenues(venues):
    
    venues_list = []
    
    for venue_id in venues:
        venues_list.append(getVenueDetails(venue_id))
    
    #print("looks find",venues_list)
    det_venues_df = pd.DataFrame(venues_list)
    
    return det_venues_df

# %%
df_ts = getDetailsforallVenues(unique_venues['Venue Id'])
df_ts
# Out:
#      likes  rating  ratingSignals  reasons_count reasons_item_reasonname_1  \
# 0       62     7.6             95              1            rawLikesReason
# 1       62     7.6             95              1            rawLikesReason
# 2       62     7.6             95              1            rawLikesReason
# 3       62     7.6             95              1            rawLikesReason
# 4       62     7.6             95              1            rawLikesReason
# 5       62     7.6             95              1            rawLikesReason
# 6       62     7.6             95              1            rawLikesReason
# 7       62     7.6             95              1            rawLikesReason
# 8       62     7.6             95              1            rawLikesReason
# 9       62     7.6             95              1            rawLikesReason
# 10      62     7.6             95              1            rawLikesReason
# 11      62     7.6             95              1            rawLikesReason
# 12      62     7.6             95              1            rawLikesReason
# 13      62     7.6             95              1            rawLikesReason
# 14      62     7.6             95              1            rawLikesReason
# 15      62     7.6             95              1            rawLikesReason
# 16      62     7.6             95              1            rawLikesReason
# 17      62     7.6             95              1            rawLikesReason
# 18      62     7.6             95              1            rawLikesReason
# 19      62     7.6             95              1            rawLikesReason
# 20      62     7.6             95              1            rawLikesReason
# 21      62     7.6             95              1            rawLikesReason
# 22      62     7.6             95              1            rawLikesReason
# 23      62     7.6             95              1            rawLikesReason
# 24      62     7.6             95              1            rawLikesReason
# 25      62     7.6             95              1            rawLikesReason
# 26      62     7.6             95              1            rawLikesReason
# 27      62     7.6             95              1            rawLikesReason
# 28      62     7.6             95              1            rawLikesReason
# 29      62     7.6             95              1            rawLikesReason
# ..     ...     ...            ...            ...                       ...
# 581     62     7.6             95              1            rawLikesReason
# 582     62     7.6             95              1            rawLikesReason
# 583     62     7.6             95              1            rawLikesReason
# 584     62     7.6             95              1            rawLikesReason
# 585     62     7.6             95              1            rawLikesReason
# 586     62     7.6             95              1            rawLikesReason
# 587     62     7.6             95              1            rawLikesReason
# 588     62     7.6             95              1            rawLikesReason
# 589     62     7.6             95              1            rawLikesReason
# 590     62     7.6             95              1            rawLikesReason
# 591     62     7.6             95              1            rawLikesReason
# 592     62     7.6             95              1            rawLikesReason
# 593     62     7.6             95              1            rawLikesReason
# 594     62     7.6             95              1            rawLikesReason
# 595     62     7.6             95              1            rawLikesReason
# 596     62     7.6             95              1            rawLikesReason
# 597     62     7.6             95              1            rawLikesReason
# 598     62     7.6             95              1            rawLikesReason
# 599     62     7.6             95              1            rawLikesReason
# 600     62     7.6             95              1            rawLikesReason
# 601     62     7.6             95              1            rawLikesReason
# 602     62     7.6             95              1            rawLikesReason
# 603     62     7.6             95              1            rawLikesReason
# 604     62     7.6             95              1            rawLikesReason
# 605     62     7.6             95              1            rawLikesReason
# 606     62     7.6             95              1            rawLikesReason
# 607     62     7.6             95              1            rawLikesReason
# 608     62     7.6             95              1            rawLikesReason
# 609     62     7.6             95              1            rawLikesReason
# 610     62     7.6             95              1            rawLikesReason
#
#              reasons_item_summary_1 reasons_item_type_1  tip_count  \
# 0    Lots of people like this place             general         24
# 1    Lots of people like this place             general         24
# 2    Lots of people like this place             general         24
# 3    Lots of people like this place             general         24
# 4    Lots of people like this place             general         24
# 5    Lots of people like this place             general         24
# 6    Lots of people like this place             general         24
# 7    Lots of people like this place             general         24
# 8    Lots of people like this place             general         24
# 9    Lots of people like this place             general         24
# 10   Lots of people like this place             general         24
# 11   Lots of people like this place             general         24
# 12   Lots of people like this place             general         24
# 13   Lots of people like this place             general         24
# 14   Lots of people like this place             general         24
# 15   Lots of people like this place             general         24
# 16   Lots of people like this place             general         24
# 17   Lots of people like this place             general         24
# 18   Lots of people like this place             general         24
# 19   Lots of people like this place             general         24
# 20   Lots of people like this place             general         24
# 21   Lots of people like this place             general         24
# 22   Lots of people like this place             general         24
# 23   Lots of people like this place             general         24
# 24   Lots of people like this place             general         24
# 25   Lots of people like this place             general         24
# 26   Lots of people like this place             general         24
# 27   Lots of people like this place             general         24
# 28   Lots of people like this place             general         24
# 29   Lots of people like this place             general         24
# ..                              ...                 ...        ...
# 581  Lots of people like this place             general         24
# 582  Lots of people like this place             general         24
# 583  Lots of people like this place             general         24
# 584  Lots of people like this place             general         24
# 585  Lots of people like this place             general         24
# 586  Lots of people like this place             general         24
# 587  Lots of people like this place             general         24
# 588  Lots of people like this place             general         24
# 589  Lots of people like this place             general         24
# 590  Lots of people like this place             general         24
# 591  Lots of people like this place             general         24
# 592  Lots of people like this place             general         24
# 593  Lots of people like this place             general         24
# 594  Lots of people like this place             general         24
# 595  Lots of people like this place             general         24
# 596  Lots of people like this place             general         24
# 597  Lots of people like this place             general         24
# 598  Lots of people like this place             general         24
# 599  Lots of people like this place             general         24
# 600  Lots of people like this place             general         24
# 601  Lots of people like this place             general         24
# 602  Lots of people like this place             general         24
# 603  Lots of people like this place             general         24
# 604  Lots of people like this place             general         24
# 605  Lots of people like this place             general         24
# 606  Lots of people like this place             general         24
# 607  Lots of people like this place             general         24
# 608  Lots of people like this place             general         24
# 609  Lots of people like this place             general         24
# 610  Lots of people like this place             general         24
#
#                      venue_id  verified
# 0    50a01c82e4b0a0263fcfdcb9      True
# 1    4ba5156cf964a520b6da38e3      True
# 2    4bb4ccb486a8d13a7ce1de7f      True
# 3    4b0eb057f964a520b75923e3      True
# 4    4c18e819d4d9c9284e19f029      True
# 5    4b48c217f964a520b25526e3      True
# 6    4b4fd4a9f964a520fd1627e3      True
# 7    4b22e0a0f964a520544f24e3      True
# 8    4b7aa47ef964a520fa342fe3      True
# 9    56d484efcd10b98f5098c328      True
# 10   5695827b498e0ff9549dd8fb      True
# 11   4b71ff80f964a52035692de3      True
# 12   56945d1c498e11466e96405f      True
# 13   4aec60d6f964a5207cc621e3      True
# 14   4fa30e16e4b0e966814a026e      True
# 15   4b049809f964a520725522e3      True
# 16   4e21f9fbcc3fee7eee221f0f      True
# 17   4bdaf4cb3904a5930902489e      True
# 18   4bd6e35d637ba5933ad3f870      True
# 19   4b59d0fbf964a520bb9928e3      True
# 20   4b00bfb8f964a520f84022e3      True
# 21   5307aeba11d2dbce9bcb6a97      True
# 22   5a443198851de55b9ee20ca2      True
# 23   50f48f2fe4b0eacffb119e25      True
# 24   4bd8ab0ce914a59345fb53fa      True
# 25   524ac4b1498e8498a174a9a0      True
# 26   4f691346e4b0de8712c745c4      True
# 27   4ae591a0f964a520eda021e3      True
# 28   55895716498eaf69c53e1042      True
# 29   4d95ec43e07ea35d4592b202      True
# ..                        ...       ...
# 581  5426999c498eabdbcf7820ad      True
# 582  523de1ec11d25bd29bf7ee53      True
# 583  4da3c293c6e96ea8a72af05d      True
# 584  5204192a498ee4fd36e98821      True
# 585  4fb3ab45e4b0fb410bb98986      True
# 586  4bd612464e32d13aed06c280      True
# 587  4ba50e5bf964a520a2d638e3      True
# 588  52f524c8498e098de17432e1      True
# 589  4c0efdd32466a593ac0f7a21      True
# 590  4f09b555c2ee103d7a249a66      True
# 591  4c6edcd7ab3f199cc170af5c      True
# 592  4c2630ca5c5ca59364a545fe      True
# 593  5589f297498ef389a0621926      True
# 594  4bb767adf562ef3b85583197      True
# 595  4f1b55bce4b095bc45a762f2      True
# 596  5b7336d29d7468002c706a88      True
# 597  4d0f8aa786ee8eecb196659e      True
# 598  4ed94bb729c2b9122714e093      True
# 599  4bf2e946706e20a169a1a798      True
# 600  4ba4be14f964a520d9b038e3      True
# 601  4bca07a1fb84c9b6c7341c3e      True
# 602  4c8bc24fc37a6dcb5db1f07a      True
# 603  4b57bf2ef964a5200b3f28e3      True
# 604  4c66db2be1da1b8de02b9cc3      True
# 605  57dd7e18498ea7530ee6d899      True
# 606  52068c12498e0645e32b6385      True
# 607  4cf431121d18a1435e7a64ec      True
# 608  4eb52e78991165b7624776dc      True
# 609  4c77c2f3947ca1cd1a4b4837      True
# 610  4b4d0dedf964a52059c926e3      True
#
# [611 rows x 10 columns]

# %%
unique_venues.merge(df_ts,left_on='Venue Id',right_on='venue_id')
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 0                       The Beaches West, India Bazaar              43.668999
# 1                                             Rosedale              43.679563
# 2                                    Hillcrest Village              43.803762
# 3                    Bedford Park, Lawrence Manor East              43.733283
# 4                                      Don Mills North              43.745906
# 5                                     Willowdale South              43.770120
# 6                                     Victoria Village              43.725882
# 7                                        Lawrence Park              43.728020
# 8                      Woodbine Gardens, Parkview Hill              43.706397
# 9                                      York Mills West              43.752758
# 10                        Fairview, Henry Farm, Oriole              43.778517
# 11                                           Parkwoods              43.753259
# 12   Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 13                                          Davisville              43.704324
# 14           Chinatown, Grange Park, Kensington Market              43.653206
# 15                                   Maryvale, Wexford              43.750071
# 16                                     Studio District              43.659526
# 17                                              Woburn              43.770992
# 18                                    Davisville North              43.712751
# 19                     Northwood Park, York University              43.767980
# 20                                    Willowdale South              43.770120
# 21                                           Agincourt              43.794200
# 22   Dorset Park, Scarborough Town Centre, Wexford ...              43.757410
# 23                                 Scarborough Village              43.744734
# 24                                           Agincourt              43.794200
# 25                                            Rosedale              43.679563
# 26                    Flemingdon Park, Don Mills South              43.725900
# 27                         Birch Cliff, Cliffside West              43.692657
# 28                     Woodbine Gardens, Parkview Hill              43.706397
# 29                    Flemingdon Park, Don Mills South              43.725900
# ..                                                 ...                    ...
# 581  Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 582                                        Upper Rouge              43.836125
# 583                                        Upper Rouge              43.836125
# 584  Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 585  Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 586  Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
#
# 592       -79.392462           9703                   Gym     62     7.6
# 593       -79.682865           7222    Athletics & Sports     62     7.6
# 594       -79.699496           8690     Recreation Center     62     7.6
# 595       -79.688210           8240    Athletics & Sports     62     7.6
# 596       -79.699878           9007                   Gym     62     7.6
# 597       -79.485634           8422  Gym / Fitness Center     62     7.6
# 598       -79.515506           2471          Skating Rink     62     7.6
# 599       -79.714913           9731                   Gym     62     7.6
# 600       -79.505995           8490          Skating Rink     62     7.6
# 601       -79.705024           9413          Skating Rink     62     7.6
# 602       -79.265927           9182  Gym / Fitness Center     62     7.6
# 603       -79.257636           7502           Event Space     62     7.6
# 604       -79.289501           7834                  Park     62     7.6
# 605       -79.243383           8484           Sports Club     62     7.6
# 606       -79.235541           3843        Baseball Field     62     7.6
# 607       -79.287282           7731      Community Center     62     7.6
# 608       -79.282153           8849          Hockey Arena     62     7.6
# 609       -79.312684           9328          Skating Rink     62     7.6
# 610       -79.313210           9376           Curling Ice     62     7.6
#
#      ratingSignals  reasons_count reasons_item_reasonname_1  \
# 0               95              1            rawLikesReason
# 1               95              1            rawLikesReason
# 2               95              1            rawLikesReason
# 3               95              1            rawLikesReason
# 4               95              1            rawLikesReason
# 5               95              1            rawLikesReason
# 6               95              1            rawLikesReason
# 7               95              1            rawLikesReason
# 8               95              1            rawLikesReason
# 9               95              1            rawLikesReason
# 10              95              1            rawLikesReason
# 11              95              1            rawLikesReason
# 12              95              1            rawLikesReason
# 13              95              1            rawLikesReason
# 14              95              1            rawLikesReason
# 15              95              1            rawLikesReason
# 16              95              1            rawLikesReason
# 17              95              1            rawLikesReason
# 18              95              1            rawLikesReason
# 19              95              1            rawLikesReason
# 20              95              1            rawLikesReason
# 21              95              1            rawLikesReason
# 22              95              1            rawLikesReason
# 23              95              1            rawLikesReason
# 24              95              1            rawLikesReason
# 25              95              1            rawLikesReason
# 26              95              1            rawLikesReason
# 27              95              1            rawLikesReason
# 28              95              1            rawLikesReason
# 29              95              1            rawLikesReason
# ..             ...            ...                       ...
# 581             95              1            rawLikesReason
# 582             95              1            rawLikesReason
# 583             95              1            rawLikesReason
# 584             95              1            rawLikesReason
# 585             95              1            rawLikesReason
# 586             95              1            rawLikesReason
# 587             95              1            rawLikesReason
# 588             95              1            rawLikesReason
# 589             95              1            rawLikesReason
# 590             95              1            rawLikesReason
# 591             95              1            rawLikesReason
# 592             95              1            rawLikesReason
# 593             95              1            rawLikesReason
# 594             95              1            rawLikesReason
# 595             95              1            rawLikesReason
# 596             95              1            rawLikesReason
# 597             95              1            rawLikesReason
# 598             95              1            rawLikesReason
# 599             95              1            rawLikesReason
# 600             95              1            rawLikesReason
# 601             95              1            rawLikesReason
# 602             95              1            rawLikesReason
# 603             95              1            rawLikesReason
# 604             95              1            rawLikesReason
# 605             95              1            rawLikesReason
# 606             95              1            rawLikesReason
# 607             95              1            rawLikesReason
# 608             95              1            rawLikesReason
# 609             95              1            rawLikesReason
# 610             95              1            rawLikesReason
#
#              reasons_item_summary_1 reasons_item_type_1  tip_count  \
# 0    Lots of people like this place             general         24
# 1    Lots of people like this place             general         24
# 2    Lots of people like this place             general         24
# 3    Lots of people like this place             general         24
# 4    Lots of people like this place             general         24
# 5    Lots of people like this place             general         24
# 6    Lots of people like this place             general         24
# 7    Lots of people like this place             general         24
# 8    Lots of people like this place             general         24
# 9    Lots of people like this place             general         24
# 10   Lots of people like this place             general         24
# 11   Lots of people like this place             general         24
# 12   Lots of people like this place             general         24
# 13   Lots of people like this place             general         24
# 14   Lots of people like this place             general         24
# 15   Lots of people like this place             general         24
# 16   Lots of people like this place             general         24
# 17   Lots of people like this place             general         24
# 18   Lots of people like this place             general         24
# 19   Lots of people like this place             general         24
# 20   Lots of people like this place             general         24
# 21   Lots of people like this place             general         24
# 22   Lots of people like this place             general         24
# 23   Lots of people like this place             general         24
# 24   Lots of people like this place             general         24
# 25   Lots of people like this place             general         24
# 26   Lots of people like this place             general         24
# 27   Lots of people like this place             general         24
# 28   Lots of people like this place             general         24
# 29   Lots of people like this place             general         24
# ..                              ...                 ...        ...
# 581  Lots of people like this place             general         24
# 582  Lots of people like this place             general         24
# 583  Lots of people like this place             general         24
# 584  Lots of people like this place             general         24
# 585  Lots of people like this place             general         24
# 586  Lots of people like this place             general         24
# 587  Lots of people like this place             general         24
# 588  Lots of people like this place             general         24
# 589  Lots of people like this place             general         24
# 590  Lots of people like this place             general         24
# 591  Lots of people like this place             general         24
# 592  Lots of people like this place             general         24
# 593  Lots of people like this place             general         24
# 594  Lots of people like this place             general         24
# 595  Lots of people like this place             general         24
# 596  Lots of people like this place             general         24
# 597  Lots of people like this place             general         24
# 598  Lots of people like this place             general         24
# 599  Lots of people like this place             general         24
# 600  Lots of people like this place             general         24
# 601  Lots of people like this place             general         24
# 602  Lots of people like this place             general         24
# 603  Lots of people like this place             general         24
# 604  Lots of people like this place             general         24
# 605  Lots of people like this place             general         24
# 606  Lots of people like this place             general         24
# 607  Lots of people like this place             general         24
# 608  Lots of people like this place             general         24
# 609  Lots of people like this place             general         24
# 610  Lots of people like this place             general         24
#
#                      venue_id  verified
# 0    50a01c82e4b0a0263fcfdcb9      True
# 1    4ba5156cf964a520b6da38e3      True
# 2    4bb4ccb486a8d13a7ce1de7f      True
# 3    4b0eb057f964a520b75923e3      True
# 4    4c18e819d4d9c9284e19f029      True
# 5    4b48c217f964a520b25526e3      True
# 6    4b4fd4a9f964a520fd1627e3      True
# 7    4b22e0a0f964a520544f24e3      True
# 8    4b7aa47ef964a520fa342fe3      True
# 9    56d484efcd10b98f5098c328      True
# 10   5695827b498e0ff9549dd8fb      True
# 11   4b71ff80f964a52035692de3      True
# 12   56945d1c498e11466e96405f      True
# 13   4aec60d6f964a5207cc621e3      True
# 14   4fa30e16e4b0e966814a026e      True
# 15   4b049809f964a520725522e3      True
# 16   4e21f9fbcc3fee7eee221f0f      True
# 17   4bdaf4cb3904a5930902489e      True
# 18   4bd6e35d637ba5933ad3f870      True
# 19   4b59d0fbf964a520bb9928e3      True
# 20   4b00bfb8f964a520f84022e3      True
# 21   5307aeba11d2dbce9bcb6a97      True
# 22   5a443198851de55b9ee20ca2      True
# 23   50f48f2fe4b0eacffb119e25      True
# 24   4bd8ab0ce914a59345fb53fa      True
# 25   524ac4b1498e8498a174a9a0      True
# 26   4f691346e4b0de8712c745c4      True
# 27   4ae591a0f964a520eda021e3      True
# 28   55895716498eaf69c53e1042      True
# 29   4d95ec43e07ea35d4592b202      True
# ..                        ...       ...
# 581  5426999c498eabdbcf7820ad      True
# 582  523de1ec11d25bd29bf7ee53      True
# 583  4da3c293c6e96ea8a72af05d      True
# 584  5204192a498ee4fd36e98821      True
# 585  4fb3ab45e4b0fb410bb98986      True
# 586  4bd612464e32d13aed06c280      True
# 587  4ba50e5bf964a520a2d638e3      True
# 588  52f524c8498e098de17432e1      True
# 589  4c0efdd32466a593ac0f7a21      True
# 590  4f09b555c2ee103d7a249a66      True
# 591  4c6edcd7ab3f199cc170af5c      True
# 592  4c2630ca5c5ca59364a545fe      True
# 593  5589f297498ef389a0621926      True
# 594  4bb767adf562ef3b85583197      True
# 595  4f1b55bce4b095bc45a762f2      True
# 596  5b7336d29d7468002c706a88      True
# 597  4d0f8aa786ee8eecb196659e      True
# 598  4ed94bb729c2b9122714e093      True
# 599  4bf2e946706e20a169a1a798      True
# 600  4ba4be14f964a520d9b038e3      True
# 601  4bca07a1fb84c9b6c7341c3e      True
# 602  4c8bc24fc37a6dcb5db1f07a      True
# 603  4b57bf2ef964a5200b3f28e3      True
# 604  4c66db2be1da1b8de02b9cc3      True
# 605  57dd7e18498ea7530ee6d899      True
# 606  52068c12498e0645e32b6385      True
# 607  4cf431121d18a1435e7a64ec      True
# 608  4eb52e78991165b7624776dc      True
# 609  4c77c2f3947ca1cd1a4b4837      True
# 610  4b4d0dedf964a52059c926e3      True
#
# [611 rows x 19 columns]

# %%
def sort_venue_by_distance(df):
    return df.sort_values(by=['Venue Distance'],ascending=True)

# %%
ocga = sort_venue_by_distance(toronto_venues.loc[toronto_venues['Venue']== 'Planet Fitness North Scarborough'])
ocga.head()
# Out:
#                                            Neighborhood  \
# 8337  Agincourt North, L'Amoreaux East, Milliken, St...
# 8813                                    L'Amoreaux West
# 7638                                          Agincourt
# 8039            Clarks Corners, Sullivan, Tam O'Shanter
# 2579                                  Hillcrest Village
#
#       Neighborhood Latitude  Neighborhood Longitude                  Venue Id  \
# 8337              43.815252              -79.284577  56945d1c498e11466e96405f
# 8813              43.799525              -79.318389  56945d1c498e11466e96405f
# 7638              43.794200              -79.262029  56945d1c498e11466e96405f
# 8039              43.781638              -79.304302  56945d1c498e11466e96405f
# 2579              43.803762              -79.363452  56945d1c498e11466e96405f
#
#                                  Venue  Venue Latitude  Venue Longitude  \
# 8337  Planet Fitness North Scarborough       43.824095       -79.301411
# 8813  Planet Fitness North Scarborough       43.824095       -79.301411
# 7638  Planet Fitness North Scarborough       43.824095       -79.301411
# 8039  Planet Fitness North Scarborough       43.824095       -79.301411
# 2579  Planet Fitness North Scarborough       43.824095       -79.301411
#
#       Venue Distance Venue Category
# 8337            1672            Gym
# 8813            3056            Gym
# 7638            4591            Gym
# 8039            4732            Gym
# 2579            5473            Gym

# %%
pd.DataFrame(toronto_venues.groupby('Neighborhood').count()['Venue'])
# Out:
#                                                     Venue
# Neighborhood
# Adelaide, King, Richmond                              100
# Agincourt                                             100
# Agincourt North, L'Amoreaux East, Milliken, Ste...    100
# Albion Gardens, Beaumond Heights, Humbergate, J...     77
# Alderwood, Long Branch                                100
# Bathurst Manor, Downsview North, Wilson Heights       100
# Bayview Village                                       100
# Bedford Park, Lawrence Manor East                     100
# Berczy Park                                           100
# Birch Cliff, Cliffside West                           100
# Bloordale Gardens, Eringate, Markland Wood, Old...    100
# Brockton, Exhibition Place, Parkdale Village          100
# Business Reply Mail Processing Centre 969 Eastern     100
# CFB Toronto, Downsview East                           100
# CN Tower, Bathurst Quay, Island airport, Harbou...    100
# Cabbagetown, St. James Town                           100
# Caledonia-Fairbanks                                   100
# Canada Post Gateway Processing Centre                 100
# Cedarbrae                                             100
# Central Bay Street                                    100
# Chinatown, Grange Park, Kensington Market             100
# Christie                                              100
# Church and Wellesley                                  100
# Clairlea, Golden Mile, Oakridge                       100
# Clarks Corners, Sullivan, Tam O'Shanter               100
# Cliffcrest, Cliffside, Scarborough Village West        93
# Cloverdale, Islington, Martin Grove, Princess G...    100
# Commerce Court, Victoria Hotel                        100
# Davisville                                            100
# Davisville North                                      100
# ...                                                   ...
# Parkdale, Roncesvalles                                100
# Parkwoods                                             100
# Queen's Park                                          100
# Rosedale                                              100
# Roselawn                                              100
# Rouge, Malvern                                         71
# Runnymede, Swansea                                    100
# Ryerson, Garden District                              100
# Scarborough Village                                   100
# Silver Hills, York Mills                              100
# St. James Town                                        100
# Stn A PO Boxes 25 The Esplanade                       100
# Studio District                                       100
# The Annex, North Midtown, Yorkville                   100
# The Beaches                                           100
# The Beaches West, India Bazaar                        100
# The Danforth West, Riverdale                          100
# The Junction North, Runnymede                         100
# The Kingsway, Montgomery Road, Old Mill North         100
# Thorncliffe Park                                      100
# Upper Rouge                                            84
# Victoria Village                                      100
# Westmount                                              78
# Weston                                                100
# Willowdale South                                      100
# Willowdale West                                       100
# Woburn                                                 83
# Woodbine Gardens, Parkview Hill                       100
# Woodbine Heights                                      100
# York Mills West                                       100
#
# [103 rows x 1 columns]

# %%
toronto_venues.shape
# Out:
# (10077, 10)

# %%
extracted_venues = toronto_venues[['Venue','Venue Id','Venue Latitude','Venue Longitude']]
extracted_venues.shape
# Out:
# (10077, 4)

# %%
extracted_venues.loc[~extracted_venues.duplicated()]
# Out:
#                                                   Venue  \
# 0                                  Monarch Park Stadium
# 1                              Toronto Lawn Tennis Club
# 2      GoodLife Fitness North York Steeles and Woodbine
# 3              Toronto Cricket Skating and Curling Club
# 4                                            LA Fitness
# 5                           Douglas Snow Aquatic Centre
# 6                 North Beach Indoor Volleyball Academy
# 7                                          Granite Club
# 8                                  East York Gymnastics
# 9                GoodLife Fitness North York York Mills
# 10            GoodLife Fitness North York Sheppard East
# 11                                   Fitness Connection
# 12                     Planet Fitness North Scarborough
# 13    GoodLife Fitness Toronto Mount Pleasant and Da...
# 14                                           Barreworks
# 15         GoodLife Fitness North York Victoria Terrace
# 16                                           Rock Oasis
# 17                                           LA Fitness
# 18          GoodLife Fitness Scarborough Cedarbrae Mall
# 19                    GoodLife Fitness Toronto Dunfield
# 20                                        Mayfair Clubs
# 21           GoodLife Fitness North York Madison Centre
# 22                                            World Gym
# 23                                           LA Fitness
# 24                                     Goodlife Fitness
# 25              GoodLife Fitness Scarborough Markington
# 26    GoodLife Fitness Scarborough Town Centre Women...
# 27                                      Crossfit Metric
# 28                       E. T. Seton PARK Archery Range
# 29                                      Variety Village
# ...                                                 ...
# 8403                   My Gym Children's Fitness Center
# 8411                                Markham Soccer Club
# 8424                           Within Range Golf Centre
# 8428                           Angus Glen Tennis Centre
# 8429                     York Downs Golf & Country Club
# 8430                    Lee's Badminton Training Centre
# 8632                                       Panorama Gym
# 8673                               Oasis Fitness Centre
# 8716                             Neptune Fitness Centre
# 8717                                       Bang Fitness
# 8720                        The Matrix Gym (City Place)
# 8735                                     Battle Archery
# 8736                      Earnscliffe Recreation Centre
# 8749                                  Peel Archery Club
# 8775             GoodLife Fitness Brampton Woodhill Gym
# 9172                                    The Motion Room
# 9177                                    Anytime Fitness
# 9206                     Colonel Samuel Smith Ice Trail
# 9257                                  Rogers Campus Gym
# 9288                                      Lambton Arena
# 9290                            Varsity Training Centre
# 9333                                   CrossFit Markham
# 9351                         Mount Joy Community Centre
# 9357                                    Centennial park
# 9359             Cornerstone Christian Community Church
# 9362                                        Legacy Park
# 9370                        Centennial Community Centre
# 9373                                    Mount Joy Arena
# 9375           Crosby Memorial Community Centre & Arena
# 9376                            Unionville Curling Club
#
#                       Venue Id  Venue Latitude  Venue Longitude
# 0     50a01c82e4b0a0263fcfdcb9       43.678144       -79.324038
# 1     4ba5156cf964a520b6da38e3       43.680667       -79.388559
# 2     4bb4ccb486a8d13a7ce1de7f       43.813541       -79.344064
# 3     4b0eb057f964a520b75923e3       43.739660       -79.418732
# 4     4c18e819d4d9c9284e19f029       43.747665       -79.347077
# 5     4b48c217f964a520b25526e3       43.767317       -79.414982
# 6     4b4fd4a9f964a520fd1627e3       43.737191       -79.323714
# 7     4b22e0a0f964a520544f24e3       43.733043       -79.381986
# 8     4b7aa47ef964a520fa342fe3       43.710654       -79.309279
# 9     56d484efcd10b98f5098c328       43.744604       -79.406346
# 10    5695827b498e0ff9549dd8fb       43.772819       -79.328195
# 11    4b71ff80f964a52035692de3       43.727473       -79.341707
# 12    56945d1c498e11466e96405f       43.824095       -79.301411
# 13    4aec60d6f964a5207cc621e3       43.698087       -79.387274
# 14    51606062e4b0878cf540f4a2       43.714070       -79.400109
# 15    4b049809f964a520725522e3       43.742234       -79.313351
# 16    4e21f9fbcc3fee7eee221f0f       43.665880       -79.342794
# 17    52ec60c1498e0c441582be5f       43.690360       -79.291339
head()
# Out:
#                              Neighborhood  Neighborhood Latitude  \
# 6571                     Davisville North              43.712751
# 7749                           Davisville              43.704324
# 7148                   North Toronto West              43.715383
# 6072                             Roselawn              43.711695
# 6673  Forest Hill North, Forest Hill West              43.696948
#
#       Neighborhood Longitude                  Venue Id  Venue Likes  \
# 6571              -79.390197  4bd6e35d637ba5933ad3f870           62
# 7749              -79.388790  4bd6e35d637ba5933ad3f870           62
# 7148              -79.405678  4bd6e35d637ba5933ad3f870           62
# 6072              -79.416936  4bd6e35d637ba5933ad3f870           62
# 6673              -79.411307  4bd6e35d637ba5933ad3f870           62
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 6571  GoodLife Fitness Toronto Dunfield       43.708093       -79.395981
# 7749  GoodLife Fitness Toronto Dunfield       43.708093       -79.395981
# 7148  GoodLife Fitness Toronto Dunfield       43.708093       -79.395981
# 6072  GoodLife Fitness Toronto Dunfield       43.708093       -79.395981
# 6673  GoodLife Fitness Toronto Dunfield       43.708093       -79.395981
#
#       Venue Distance Venue Category
# 6571             696            Gym
# 7749             714            Gym
# 7148            1125            Gym
# 6072            1733            Gym
# 6673            1749            Gym

# %%
mgd_pos_df.loc[mgd_pos_df['PostalCode'] == 'M4P']
# Out:
#    PostalCode          Borough      Neighborhood   Latitude  Longitude
# 67        M4P  Central Toronto  Davisville North  43.712751 -79.390197

# %% [markdown]
# ###### Unique Venue Categories

# %%
toronto_venues.shape
# Out:
# (10077, 10)

# %% [markdown]
# Sports Club

# %%
toronto_venues['Venue Category'].unique()
# Out:
# array(['Athletics & Sports', 'Gym', 'Sports Club', 'Gym / Fitness Center',
#        'Pool', 'Yoga Studio', 'Climbing Gym', 'Office', 'Soccer Field',
#        'Golf Course', 'Baseball Field', 'Park',
#        'Residential Building (Apartment / Condo)', 'Community Center',
#        'Tennis Court', 'Cycle Studio', 'Arcade', 'Badminton Court',
#        'College Gym', 'Gym Pool', 'Basketball Court', 'College Stadium',
#        'Soccer Stadium', 'College Rec Center', 'Plaza', 'Stadium',
#        'Building', 'Martial Arts Dojo', 'Trail', 'Elementary School',
#        'Event Space', 'Track', 'Curling Ice', 'Playground', 'Social Club',
#        'Skating Rink', 'Hockey Arena', 'School', 'Paintball Field',
#        'Swim School', 'Hotel', 'Other Great Outdoors', 'Field',
#        'Skate Park', 'Physical Therapist', 'Hotel Pool', 'Water Park',
#        'Hockey Field', 'Weight Loss Center', 'Boxing Gym', 'High School',
#        'Pilates Studio', 'Recreation Center'], dtype=object)

# %%
toronto_venues.loc[toronto_venues['Venue Category'] == 'Housing Development']
# Out:
# Empty DataFrame
# Columns: [Neighborhood, Neighborhood Latitude, Neighborhood Longitude, Venue Id, Venue Likes, Venue, Venue Latitude, Venue Longitude, Venue Distance, Venue Category]
# Index: []

# %%
unexp = toronto_venues.loc[toronto_venues['Venue Category'].str.contains('Restaurant')]['Venue Category'].unique()

# %%
pd.DataFrame(toronto_venues.loc[~toronto_venues['Venue Category'].str.match('(Club|Sport|Gym|Stadium|Fit|Golf|Park)')]['Venue Category'].unique()).values
# Out:
# array([['Athletics & Sports'],
#        ['Pool'],
#        ['Yoga Studio'],
#        ['Climbing Gym'],
#        ['Office'],
#        ['Soccer Field'],
#        ['Baseball Field'],
#        ['Residential Building (Apartment / Condo)'],
#        ['Community Center'],
#        ['Tennis Court'],
#        ['Cycle Studio'],
#        ['Arcade'],
#        ['Badminton Court'],
#        ['College Gym'],
#        ['Basketball Court'],
#        ['College Stadium'],
#        ['Soccer Stadium'],
#        ['College Rec Center'],
#        ['Plaza'],
#        ['Building'],
#        ['Martial Arts Dojo'],
#        ['Trail'],
#        ['Elementary School'],
#        ['Event Space'],
#        ['Track'],
#        ['Curling Ice'],
#        ['Playground'],
#        ['Social Club'],
#        ['Skating Rink'],
#        ['Hockey Arena'],
#        ['School'],
#        ['Paintball Field'],
#        ['Swim School'],
#        ['Hotel'],
#        ['Other Great Outdoors'],
#        ['Field'],
#        ['Skate Park'],
#        ['Physical Therapist'],
#        ['Hotel Pool'],
#        ['Water Park'],
#        ['Hockey Field'],
#        ['Weight Loss Center'],
#        ['Boxing Gym'],
#        ['High School'],
#        ['Pilates Studio'],
#        ['Recreation Center']], dtype=object)

# %%
toronto_venues.loc[toronto_venues['Venue Category'] == 'Athletics & Sports']

# %%
toronto_venues.shape

# %%
toronto_gym = toronto_venues

# %%
# create map of Downtown Toronto using latitude and longitude values
map_toronto_gym = folium.Map(location=[latitude, longitude], zoom_start=10)

count = 0
# add markers to map
for lat, lng, venue, neighborhood in zip(toronto_gym['Venue Latitude'], toronto_gym['Venue Longitude'], toronto_gym['Venue'],toronto_gym['Neighborhood']):
    label = '{}, {}'.format(venue,neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='green').add_to(map_toronto_gym)  
    count += 1
    if count > 800:
        break
map_toronto_gym

# %%
toronto_res = toronto_venues.loc[toronto_venues['Venue Category'].str.contains('Restaurant')]
toronto_res.head()

# %%
# create map of Downtown Toronto using latitude and longitude values
map_toronto_res = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, venue, neighborhood in zip(toronto_res['Venue Latitude'], toronto_res['Venue Longitude'], toronto_res['Venue'],toronto_res['Neighborhood']):
    label = '{}, {}'.format(venue,neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='orange').add_to(map_toronto_res)  
    
map_toronto_res

# %% [markdown]
# ###### Extracted Venues from each Neighbourhood

# %%
toronto_venues.head()

# %% [markdown]
# ###### Count of the Venues Receied for each Neighborhood.
# ###### Note: As highlighted above, API returned less venues for few neighbourhoods as it could only find those within the given radius

# %%
pd.DataFrame(toronto_venues.groupby('Neighborhood').count()['Venue'])

# %% [markdown]
# ###### Analyze based on Venue Category

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()

# %% [markdown]
# ###### Shape of the Dataframe after the onehot encoding

# %%
toronto_onehot.shape

# %% [markdown]
# ###### Group the Neighbourhoods with the corresponding encoded rows to see the most

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()

# %% [markdown]
# ###### Shape of the Grouped Dataframe

# %%
toronto_grouped.shape

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ###### Get & Print the Top 5 most common venues

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(10)

# %% [markdown]
# ###### Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
toronto_grouped_clustering.head()

# %% [markdown]
# ###### Add clustering labels

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!

# %% [markdown]
# ###### Create a map with clusted labels (produced in different colors)

# %%
toronto_merged = toronto_merged.dropna()
toronto_merged.head()

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)+7))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[np.int(cluster-1)]).add_to(map_clusters)
       
map_clusters

# %%
toronto_merged[]
