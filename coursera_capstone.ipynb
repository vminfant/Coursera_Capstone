# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ###### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import requests 
import bs4
import folium
import json
from pandas.io.json import json_normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import time

# %% [markdown]
# ###### Get Data from Wiki

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
if response.status_code == 200: 
    print ("Get Successful!")
else:
    print ("Get Failed! Check URL")
# Out:
# Get Successful!

# %% [markdown]
# ###### Payload Received From Wiki

# %%
# print(response.text) # Commented out to avoid filling the notebook with the response text

# %% [markdown]
# ###### Parse the response text using BeautifulSoap

# %%
resp_soap = bs4.BeautifulSoup(response.text, 'html.parser')
resp_soap.title
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %% [markdown]
# ### Assumptions
#  * Postal Code & Borough combination is expected have same value for all the nieighbourhoods with those combinations.
#  * **_check_\__for_\__discrepancy_** is used to shout if there are any discrepancies found while processing the rows.

# %%
def check_for_discrepancy(pos_dict,row_list):
    
    if row_list[0] in pos_dict and pos_dict[row_list[0]][0] != row_list[1]:
        print ("Warning! Existing Postal Codes and Borough combination is differeing from the new row")
        print (f"Existing Postal Code {row_list[0]} Borough {pos_dict[row_list[0]][0]}")
        print (f"New Postal Code {row_list[0]} Borough {row_list[1]}")

# %% [markdown]
# ### Approach
# * Very first table from the Response Text will be parsed to get all the Postal Codes
# * **_get_\__list_\__of_\__postal_\__codes_** will parse all the rows.
# * **_get_\__row_\__list_** will parse the columns.
# * Postal Code Dictionary (_with postal code as a Key_) is maintained to store all the parsed postal codes.
# * If Borough i.e. Column #2 is "Not Assigned", it will skip adding the rows to the Postal Code Dictionary
# * If Nieighbourhood i.e. Column #3 is "Not Assigned" but if the Borough is valid, it will assign the Borough as its neighbourhood before adding the row to the Dictionary.
# * List is maintained to keep track of the Neighbourhoods that are having same postal code
# * Another List is maintained to keep track of the rows that are having valid Borough but "Not assigned" Neighbourhood

# %%
def add_to_dictionary(pos_dict,row_list,more_nbh):
    
    if (row_list[0]) in pos_dict:
        more_nbh.append(row_list[0])
        pos_dict[row_list[0]][1] = pos_dict[row_list[0]][1] + ", " + row_list[2]
    else:
        pos_dict[row_list[0]] = [row_list[1],row_list[2]]

# %%
def get_row_list(row):
    
    row_list = []    
    for column in row:
        
        if isinstance(column,bs4.element.Tag): # Avoid processing NavigableString - Mostly newline char            
            row_list.append(column.get_text(strip=True))
            
    return row_list

# %%
def get_list_of_postal_codes(soap_msg_table):
    
    pos_dict = {}
    more_nbh = []
    na_nbh = []
    for row in soap_msg_table:
        
        if isinstance(row,bs4.element.Tag): # Avoid processing NavigableString - Mostly newline char
            row_list = get_row_list(row)
            
            if row_list[1].replace(' ','').lower() != 'notassigned' and row_list[2].replace(' ','').lower() == 'notassigned':
                na_nbh.append(row_list[0])
                row_list[2] = row_list[1]
                add_to_dictionary(pos_dict,row_list,more_nbh)
                
            elif row_list[1].replace(' ','').lower() != 'notassigned':                
                add_to_dictionary(pos_dict,row_list,more_nbh)
            
            # Check for discrepancy
            check_for_discrepancy(pos_dict,row_list)
            
    return pos_dict,more_nbh,na_nbh

# %% [markdown]
# ###### Extracting & Parsing the very first table from the response text

# %%
resp_table = resp_soap.table
postal_code_list, more_nbh, na_nbh = get_list_of_postal_codes(resp_table.tbody)

# %% [markdown]
# ###### Creating a DataFrame from the Parsed Dictionary.
# * _orient_ is used to parse the keys as Index
# * Removing the first row as it is a header from the table
# * Resetting the Index to get the DataFrame in an expected way.
# * Adding the expected column names to the DataFrame

# %%
pos_df = pd.DataFrame.from_dict(postal_code_list,orient='index')
pos_df = pos_df[1:]
pos_df = pos_df.reset_index()
pos_df.columns = ['PostalCode','Borough','Neighborhood']

# %% [markdown]
# ###### Postal Code with more than one neightbourhood - Eg : M5A is used

# %%
pos_df.loc[pos_df['PostalCode'] == 'M5A']['Neighborhood'].values
# Out:
# array(['Harbourfront, Regent Park'], dtype=object)

# %% [markdown]
# ###### All Postal Codes that are having more than one neightbourhood

# %%
pos_df.loc[pos_df['PostalCode'].isin(set(more_nbh))]
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 6          M1B       Scarborough
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 28         M3H        North York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 33         M2J        North York
# 34         M3J        North York
# 36         M5J  Downtown Toronto
# 37         M6J      West Toronto
# 38         M1K       Scarborough
# 40         M3K        North York
# 41         M4K      East Toronto
# 42         M5K  Downtown Toronto
# 43         M6K      West Toronto
# 44         M1L       Scarborough
# 45         M2L        North York
# 47         M4L      East Toronto
# 48         M5L  Downtown Toronto
# 49         M6L        North York
# 51         M1M       Scarborough
# 52         M2M        North York
# 55         M5M        North York
# 56         M6M              York
# 57         M9M        North York
# 58         M1N       Scarborough
# 63         M6N              York
# 65         M1P       Scarborough
# 68         M5P   Central Toronto
# 69         M6P      West Toronto
# 71         M1R       Scarborough
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 77         M9R         Etobicoke
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 93         M8W         Etobicoke
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 6                                       Rouge, Malvern
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 30                            Adelaide, King, Richmond
# 31                        Dovercourt Village, Dufferin
# 33                        Fairview, Henry Farm, Oriole
# 34                     Northwood Park, York University
# 36   Harbourfront East, Toronto Islands, Union Station
# 37                            Little Portugal, Trinity
# 38         East Birchmount Park, Ionview, Kennedy Park
# 40                         CFB Toronto, Downsview East
# 41                        The Danforth West, Riverdale
# 42            Design Exchange, Toronto Dominion Centre
# 43        Brockton, Exhibition Place, Parkdale Village
# 44                     Clairlea, Golden Mile, Oakridge
# 45                            Silver Hills, York Mills
# 47                      The Beaches West, India Bazaar
# 48                      Commerce Court, Victoria Hotel
# 49                  Downsview, North Park, Upwood Park
# 51     Cliffcrest, Cliffside, Scarborough Village West
# 52                             Newtonbrook, Willowdale
# 55                   Bedford Park, Lawrence Manor East
# 56      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 57                                    Emery, Humberlea
# 58                         Birch Cliff, Cliffside West
# 63                       The Junction North, Runnymede
# 65   Dorset Park, Scarborough Town Centre, Wexford ...
# 68                 Forest Hill North, Forest Hill West
# 69                       High Park, The Junction South
# 71                                   Maryvale, Wexford
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 93                              Alderwood, Long Branch
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...

# %% [markdown]
# ###### Postal Codes that were having "Not assigned" neighbourhood

# %%
pos_df.loc[pos_df['PostalCode'].isin(set(na_nbh))]
# Out:
#   PostalCode       Borough  Neighborhood
# 4        M7A  Queen's Park  Queen's Park

# %% [markdown]
# ###### Resultant DataFrame - Only first 10 rows are displayed

# %%
pos_df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park
# 3        M6A        North York  Lawrence Heights, Lawrence Manor
# 4        M7A      Queen's Park                      Queen's Park
# 5        M9A         Etobicoke                  Islington Avenue
# 6        M1B       Scarborough                    Rouge, Malvern
# 7        M3B        North York                   Don Mills North
# 8        M4B         East York   Woodbine Gardens, Parkview Hill
# 9        M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# ###### Shape of the Resultant Dataframe

# %%
print(f"{pos_df.shape}")
# Out:
# (103, 3)

# %% [markdown]
# ## Extracting & Merging Geospatial Data

# %% [markdown]
# <font color=red>**Note:**</font> I don't seem to be recieveing data that are consistent with the Geospatial Data Provided in the Assignment Section. So, i will be using the data file provided in the Assignment Section

# %%
# !wget -q http://cocl.us/Geospatial_data

# %% [markdown]
# ###### Read the data file into a DataFrame & Rename the columns to match the existing DataFrame

# %%
geo_data = pd.read_csv('Geospatial_data',header=0)
geo_data.columns = ['PostalCode','Latitude','Longitude']

# %%
geo_data.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# ###### Make sure all the postal codes are having the corresponding Latitude & Longitude values from Geospatial_data

# %%
pos_df.loc[~pos_df['PostalCode'].isin(geo_data['PostalCode'])].size
# Out:
# 0

# %% [markdown]
# ###### Merge the DataFrames based on Postal Codes

# %%
mgd_pos_df = pos_df.merge(right=geo_data,on='PostalCode')
mgd_pos_df.head(10)
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
# 5        M9A         Etobicoke                  Islington Avenue  43.667856
# 6        M1B       Scarborough                    Rouge, Malvern  43.806686
# 7        M3B        North York                   Don Mills North  43.745906
# 8        M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9        M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %% [markdown]
# ###### Shape of the Merged Dataframe

# %%
print(f"{mgd_pos_df.shape}")
# Out:
# (103, 5)

# %% [markdown]
# ## Clustering the neighbourhoods

# %%
print (f"There are {mgd_pos_df['Borough'].unique().size} unique Borough's from the merged DataFrame")
# Out:
# There are 11 unique Borough's from the merged DataFrame

# %% [markdown]
# ### Approach
# * **Only Borough's that contains the word "Toronto" will be analyzed below**.
# * https://nominatim.openstreetmap.org/ will be queried directly to get the Geocodes
# * foursquare api will be used to analyze the neighbourhoods.

# %% [markdown]
# ###### Get Geo codes for a specific location.

# %%
def get_geo_codes(area):
    longitude = ""
    latitude = ""
    try:
        # Replace the space with +
        area_str = area.replace(" ","+")
        
        # Get the Geolocation for given area
        response = requests.get('https://nominatim.openstreetmap.org/search?q='+area_str+'&format=geojson&limit=1')
        if response.status_code == 200:
            print ("Get Successful")
            
            # Extract the Latitude & Longitude from the response text
            longitude,latitude = json.loads(response.text)['features'][0]['geometry']['coordinates']
            print(f"latitude & longitude values of {area} are {latitude},{longitude}")
        else:
            print ("Get Failed!")
    except:
        pass
    
    return latitude,longitude

# %% [markdown]
# ###### Extract Latitude & Longitude for Toronto,ON

# %%
latitude,longitude = get_geo_codes('Toronto ON')
# Out:
# Get Successful
# latitude & longitude values of Toronto ON are 43.653963,-79.387207

# %% [markdown]
# #### Create a map of Toronto with neighborhoods superimposed on top.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(mgd_pos_df['Latitude'], mgd_pos_df['Longitude'], mgd_pos_df['Borough'], mgd_pos_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='green').add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Create a dataframe with Boroughs that has a word "Toronto" Note : Only this dataframe toronto_df will be analyzed futher.

# %%
toronto_df = mgd_pos_df
toronto_df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
toronto_df.shape
# Out:
# (103, 5)

# %% [markdown]
# ###### Set the Credentials for Foursquare API

# %%
CLIENT_ID = 'KGU5MEU4ZHYXQPJT2Y1B2DNRFFTV1GSD4Y5KXV0WMSFFDLQO' # your Foursquare ID
CLIENT_SECRET = 'S30A30GKJ1SITKL3YOTXQAPTCJBYQGUMONMF4H4CNVJTAVOT' # your Foursquare Secret
VERSION = '20190531' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KGU5MEU4ZHYXQPJT2Y1B2DNRFFTV1GSD4Y5KXV0WMSFFDLQO
# CLIENT_SECRET:S30A30GKJ1SITKL3YOTXQAPTCJBYQGUMONMF4H4CNVJTAVOT

# %% [markdown]
# ###### Get Nearby Venues from each Neighbourhood
# * radius is set to 10000 to have enough datapoints for each neighbourhood
# * LIMIT is set to 100 for all the neighbourhoods. However, there may be some cases with less number of records recived from the API

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=10000):
    
    LIMIT = 100
    
    # Athletics & Sports {4f4528bc4b90abdf24c9de85}, Pool {4bf58dd8d48988d15e941735},    
    CATEGORY = '4f4528bc4b90abdf24c9de85,4bf58dd8d48988d15e941735'
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            CATEGORY)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['id'],
            v['venue']['name'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['location']['distance'], 
            v['venue']['categories'][0]['name']) for v in results])
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude',
                  'Venue Id',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue Distance', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ###### Get Venues from each Neighbourhood

# %%
#toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
#                                   latitudes=toronto_df['Latitude'],
#                                   longitudes=toronto_df['Longitude']
#                                  )
#csv_export = toronto_venues.to_csv (r'toronto_dataframe.csv', index = None, header=True)
toronto_venues = pd.read_csv('toronto_dataframe.csv',header=0)
toronto_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Parkwoods              43.753259              -79.329656
# 1    Parkwoods              43.753259              -79.329656
# 2    Parkwoods              43.753259              -79.329656
# 3    Parkwoods              43.753259              -79.329656
# 4    Parkwoods              43.753259              -79.329656
#
#                    Venue Id                                             Venue  \
# 0  50a01c82e4b0a0263fcfdcb9                              Monarch Park Stadium
# 1  4ba5156cf964a520b6da38e3                          Toronto Lawn Tennis Club
# 2  4bb4ccb486a8d13a7ce1de7f  GoodLife Fitness North York Steeles and Woodbine
# 3  4b0eb057f964a520b75923e3          Toronto Cricket Skating and Curling Club
# 4  4c18e819d4d9c9284e19f029                                        LA Fitness
#
#    Venue Latitude  Venue Longitude  Venue Distance        Venue Category
# 0       43.678144       -79.324038            8373    Athletics & Sports
# 1       43.680667       -79.388559            9367    Athletics & Sports
# 2       43.813541       -79.344064            6809                   Gym
# 3       43.739660       -79.418732            7321           Sports Club
# 4       43.747665       -79.347077            1532  Gym / Fitness Center

# %%
def identify_the_closest_nh(df):
    return df.sort_values(by=['Venue Distance'],ascending=True).iloc[0]

# %%
def venues_eliminate_duplicates(df):
    venue_list = df['Venue'].unique()
    unique_venues = pd.DataFrame(columns=['Neighborhood','Neighborhood Latitude','Neighborhood Longitude','Venue Id','Venue','Venue Latitude','Venue Longitude','Venue Distance','Venue Category'])
    for venue in venue_list:
        closest = identify_the_closest_nh(df.loc[df['Venue'] == venue])
        unique_venues = unique_venues.append(closest)
    
    print (f"{unique_venues.shape[0]} Unique venues are identified for further analysis")
    return unique_venues

# %%
toronto_unique_venues = venues_eliminate_duplicates(toronto_venues)
# Out:
# 611 Unique venues are identified for further analysis

# %%
toronto_unique_venues.head()
# Out:
#                            Neighborhood  Neighborhood Latitude  \
# 4570     The Beaches West, India Bazaar              43.668999
# 8910                           Rosedale              43.679563
# 2570                  Hillcrest Village              43.803762
# 5356  Bedford Park, Lawrence Manor East              43.733283
# 676                     Don Mills North              43.745906
#
#       Neighborhood Longitude                  Venue Id  \
# 4570              -79.315572  50a01c82e4b0a0263fcfdcb9
# 8910              -79.377529  4ba5156cf964a520b6da38e3
# 2570              -79.363452  4bb4ccb486a8d13a7ce1de7f
# 5356              -79.419750  4b0eb057f964a520b75923e3
# 676               -79.352188  4c18e819d4d9c9284e19f029
#
#                                                  Venue  Venue Latitude  \
# 4570                              Monarch Park Stadium       43.678144
# 8910                          Toronto Lawn Tennis Club       43.680667
# 2570  GoodLife Fitness North York Steeles and Woodbine       43.813541
# 5356          Toronto Cricket Skating and Curling Club       43.739660
# 676                                         LA Fitness       43.747665
#
#       Venue Longitude Venue Distance        Venue Category
# 4570       -79.324038           1225    Athletics & Sports
# 8910       -79.388559            896    Athletics & Sports
# 2570       -79.344064           1900                   Gym
# 5356       -79.418732            714           Sports Club
# 676        -79.347077            455  Gym / Fitness Center

# %%
def get_attr_value(resp_dict,attribute):
    
    if attribute in resp_dict:
        return resp_dict[attribute]
    
    return ''

# %%
def has_attr(resp_dict,attribute):
    
    return attribute in resp_dict

# %%
def get_reasons(curr_resp_dict,reasons):
    
    curr_resp_dict['reasons_count'] = get_attr_value(reasons,'count')
    
    items = ()
    index = 1
    for item in reasons['items']:
        curr_resp_dict[f'reasons_item_summary_{index}'] = get_attr_value(item,'summary')
        break

# %%
def getVenueDetails(id):
    
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # make the GET request
    response_msg = requests.get(url).json()["response"]['venue']
    
    curr_resp_list = []
    curr_resp_dict = {'venue_id':id,'verified':'','tip_count':'',
                'likes':'','rating':'','ratingSignals':'','reasons_count':'',
                'reasons_item_summary_1':''}
    
    curr_resp_dict['verified'] = get_attr_value(response_msg,'verified')
    
    if has_attr(response_msg,'stats'):
        curr_resp_dict['tip_count'] = get_attr_value(response_msg['stats'],'tipCount')
        
    if has_attr(response_msg,'likes'):
        curr_resp_dict['likes'] = get_attr_value(response_msg['likes'],'count')
    
    curr_resp_dict['rating'] = get_attr_value(response_msg,'rating')
    curr_resp_dict['ratingSignals'] = get_attr_value(response_msg,'ratingSignals')
    
    if has_attr(response_msg,'reasons'):
        get_reasons(curr_resp_dict,response_msg['reasons'])
    
    return curr_resp_dict

# %%
def getDetailsforallVenues(venues):
    
    venues_list = []
    
    for venue_id in venues:
        venues_list.append(getVenueDetails(venue_id))
    
    det_venues_df = pd.DataFrame(venues_list)
    
    return det_venues_df

# %%
### uncomment this after two days 
#toronto_venue_details = getDetailsforallVenues(toronto_unique_venues['Venue Id'])
#toronto_venue_details.head()

toronto_venue_details = pd.read_csv(r'toronto_venue_details_dataframe.csv',
                                names=['likes','rating','ratingSignals','reasons_count',
                                       'reasons_item_summary_1','tip_count','venue_id','verified'])

# %%
#toronto_venue_details_2.to_csv (r'toronto_venue_details_last_dataframe.csv', index = None, header=True)

# %%
#toronto_venue_details = toronto_venue_details_1.append(toronto_venue_details_2)

# %%
toronto_venue_details.dtypes
# Out:
# likes                       int64
# rating                    float64
# ratingSignals             float64
# reasons_count               int64
# reasons_item_summary_1     object
# tip_count                   int64
# venue_id                   object
# verified                     bool
# dtype: object

# %%
toronto_mvenues = toronto_unique_venues.merge(toronto_venue_details,left_on='Venue Id',right_on='venue_id').drop('venue_id',axis=1)

# %%
toronto_mvenues['reasons_count'].unique()
# Out:
# array([0, 1])

# %%
toronto_mvenues = toronto_mvenues.drop('reasons_count',axis=1)

# %%
toronto_mvenues.loc[~(toronto_mvenues['verified'] == True)].shape
# Out:
# (466, 15)

# %%
toronto_mvenues = toronto_mvenues.drop('verified',axis=1)

# %%
toronto_mvenues.head()
# Out:
#                         Neighborhood  Neighborhood Latitude  \
# 0     The Beaches West, India Bazaar              43.668999
# 1                           Rosedale              43.679563
# 2                  Hillcrest Village              43.803762
# 3  Bedford Park, Lawrence Manor East              43.733283
# 4                    Don Mills North              43.745906
#
#    Neighborhood Longitude                  Venue Id  \
# 0              -79.315572  50a01c82e4b0a0263fcfdcb9
# 1              -79.377529  4ba5156cf964a520b6da38e3
# 2              -79.363452  4bb4ccb486a8d13a7ce1de7f
# 3              -79.419750  4b0eb057f964a520b75923e3
# 4              -79.352188  4c18e819d4d9c9284e19f029
#
#                                               Venue  Venue Latitude  \
# 0                              Monarch Park Stadium       43.678144
# 1                          Toronto Lawn Tennis Club       43.680667
# 2  GoodLife Fitness North York Steeles and Woodbine       43.813541
# 3          Toronto Cricket Skating and Curling Club       43.739660
# 4                                        LA Fitness       43.747665
#
#    Venue Longitude Venue Distance        Venue Category  likes  rating  \
# 0       -79.324038           1225    Athletics & Sports     28     8.9
# 1       -79.388559            896    Athletics & Sports     11     8.6
# 2       -79.344064           1900                   Gym     34     7.5
# 3       -79.418732            714           Sports Club     15     7.3
# 4       -79.347077            455  Gym / Fitness Center     51     8.2
#
#    ratingSignals          reasons_item_summary_1  tip_count
# 0           36.0                             NaN          7
# 1           11.0                             NaN          0
# 2           46.0  Lots of people like this place         10
# 3           22.0                             NaN          6
# 4           70.0  Lots of people like this place         20

# %%
toronto_mvenues.loc[np.isnan(toronto_mvenues['rating'])]
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 26                    Flemingdon Park, Don Mills South              43.725900
# 28                     Woodbine Gardens, Parkview Hill              43.706397
# 29                    Flemingdon Park, Don Mills South              43.725900
# 34                                     L'Amoreaux West              43.799525
# 35                                   Hillcrest Village              43.803762
# 37                     Woodbine Gardens, Parkview Hill              43.706397
# 38                            Silver Hills, York Mills              43.757490
# 42   Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 43                                   Hillcrest Village              43.803762
# 45                                    Willowdale South              43.770120
# 47                                   Hillcrest Village              43.803762
# 49                                     Studio District              43.659526
# 50     Bathurst Manor, Downsview North, Wilson Heights              43.754328
# 51   Harbourfront East, Toronto Islands, Union Station              43.640816
# 58                                    Victoria Village              43.725882
# 59                                    Victoria Village              43.725882
# 60                     Clairlea, Golden Mile, Oakridge              43.711112
# 63             Clarks Corners, Sullivan, Tam O'Shanter              43.781638
#
# 577                       Authentic Tae Kwon Do       43.830367
# 578                            Hot Yoga Markham       43.854055
# 579       Soho Metropolitan Hotel's Health Club       43.645129
# 581                            Angus Glen Arena       43.894571
# 582            My Gym Children's Fitness Center       43.901010
# 583                         Markham Soccer Club       43.895036
# 584                    Within Range Golf Centre       43.834112
# 585                    Angus Glen Tennis Centre       43.894899
# 586              York Downs Golf & Country Club       43.885894
# 587             Lee's Badminton Training Centre       43.853067
# 588                                Panorama Gym       43.637953
# 590                      Neptune Fitness Centre       43.636686
# 591                                Bang Fitness       43.647039
# 592                 The Matrix Gym (City Place)       43.642913
# 595                           Peel Archery Club       43.722626
# 596      GoodLife Fitness Brampton Woodhill Gym       43.747506
# 597                             The Motion Room       43.665434
# 598              Colonel Samuel Smith Ice Trail       43.593327
# 599                           Rogers Campus Gym       43.703808
# 600                               Lambton Arena       43.664771
# 601                     Varsity Training Centre       43.680045
# 602                            CrossFit Markham       43.906236
# 603                  Mount Joy Community Centre       43.892127
# 604                             Centennial park       43.872115
# 605      Cornerstone Christian Community Church       43.907324
# 606                                 Legacy Park       43.863084
# 608                             Mount Joy Arena       43.893364
# 609    Crosby Memorial Community Centre & Arena       43.868742
# 610                     Unionville Curling Club       43.868946
#
#      Venue Longitude Venue Distance                            Venue Category  \
# 26        -79.338759           1490                        Athletics & Sports
# 28        -79.313411            485                        Athletics & Sports
# 29        -79.331728           1141                      Gym / Fitness Center
# 34        -79.339656           1775                        Athletics & Sports
# 35        -79.371011            737                                      Pool
# 37        -79.360992           4149                                      Pool
# 38        -79.400205           3864                                      Pool
# 42        -79.305097           1685                        Athletics & Sports
# 43        -79.354347            755  Residential Building (Apartment / Condo)
# 45        -79.407887            537                          Community Center
# 47        -79.344809           2647                        Athletics & Sports
# 49        -79.340064            959                                      Pool
# 50        -79.434910            591                        Athletics & Sports
# 51        -79.379493            241                      Gym / Fitness Center
# 58        -79.327789            996                      Gym / Fitness Center
# 59        -79.327232           1087                                       Gym
# 60        -79.308781           2003                      Gym / Fitness Center
# 63        -79.280695           1952                                       Gym
# 64        -79.408652           1018                      Gym / Fitness Center
# 65        -79.319300             75                                       Gym
# 66        -79.284578            817                                       Gym
# 69        -79.406894            657                                       Gym
# 70        -79.409809            945                                       Gym
# 71        -79.387444            298                                       Gym
# 72        -79.378066           5814                              Cycle Studio
# 73        -79.394979           4356                                       Gym
# 74        -79.342074           4122                      Gym / Fitness Center
# 76        -79.395490           8597                                       Gym
# 77        -79.412895           2667                                       Gym
# 80        -79.519610            469                      Gym / Fitness Center
# ..               ...            ...                                       ...
# 576       -79.272321           6946                                  Gym Pool
# 577       -79.354569           4498                         Martial Arts Dojo
# 578       -79.337397           6053                               Yoga Studio
# 579       -79.392565           1082                      Gym / Fitness Center
# 581       -79.336175           9752                        Athletics & Sports
# 582       -79.264609           8635                                Playground
# 583       -79.261787           7957                              Soccer Field
# 584       -79.374838           7546                               Golf Course
# 585       -79.337807           9842                              Tennis Court
# 586       -79.327584           8588                               Golf Course
# 587       -79.363891           7634                           Badminton Court
# 588       -79.397996           1043                                       Gym
# 590       -79.404664           8521                                       Gym
# 591       -79.404885           9034                                       Gym
# 592       -79.392462           9703                                       Gym
# 595       -79.688210           8240                        Athletics & Sports
# 596       -79.699878           9007                                       Gym
# 597       -79.485634           8422                      Gym / Fitness Center
# 598       -79.515506           2471                              Skating Rink
# 599       -79.714913           9731                                       Gym
# 600       -79.505995           8490                              Skating Rink
# 601       -79.705024           9413                              Skating Rink
# 602       -79.265927           9182                      Gym / Fitness Center
# 603       -79.257636           7502                               Event Space
# 604       -79.289501           7834                                      Park
# 605       -79.243383           8484                               Sports Club
# 606       -79.235541           3843                            Baseball Field
# 608       -79.282153           8849                              Hockey Arena
# 609       -79.312684           9328                              Skating Rink
# 610       -79.313210           9376                               Curling Ice
#
#      likes  rating  ratingSignals reasons_item_summary_1  tip_count
# 26       1     NaN            NaN                    NaN          2
# 28       3     NaN            NaN                    NaN          4
# 29       1     NaN            NaN                    NaN          0
# 34       1     NaN            NaN                    NaN          2
# 35       3     NaN            NaN                    NaN          1
# 37       0     NaN            NaN                    NaN          2
# 38       1     NaN            NaN                    NaN          0
# 42       2     NaN            NaN                    NaN          4
# 43       0     NaN            NaN                    NaN          0
# 45       4     NaN            NaN                    NaN          0
# 47       7     NaN            NaN                    NaN          0
# 49       3     NaN            NaN                    NaN          1
# 50       1     NaN            NaN                    NaN          0
# 51       1     NaN            NaN                    NaN          0
# 58       1     NaN            NaN                    NaN          0
# 59       3     NaN            NaN                    NaN          0
# 60       1     NaN            NaN                    NaN          3
# 63       3     NaN            NaN                    NaN          0
# 64       2     NaN            NaN                    NaN          1
# 65       3     NaN            NaN                    NaN          1
# 66       3     NaN            NaN                    NaN          1
# 69       3     NaN            NaN                    NaN          0
# 70       1     NaN            NaN                    NaN          1
# 71       1     NaN            NaN                    NaN          1
# 72       1     NaN            NaN                    NaN          0
# 73       3     NaN            NaN                    NaN          0
# 74       0     NaN            NaN                    NaN          0
# 76       1     NaN            NaN                    NaN          0
# 77       2     NaN            NaN                    NaN          3
# 80       1     NaN            NaN                    NaN          0
# ..     ...     ...            ...                    ...        ...
# 576      0     NaN            NaN                    NaN          0
# 577      0     NaN            NaN                    NaN          2
# 578      3     NaN            NaN                    NaN          3
# 579      4     NaN            NaN                    NaN          1
# 581      2     NaN            NaN                    NaN          0
# 582      0     NaN            NaN                    NaN          0
# 583      3     NaN            NaN                    NaN          2
# 584      3     NaN            NaN                    NaN          1
# 585      0     NaN            NaN                    NaN          0
# 586      7     NaN            NaN                    NaN          0
# 587      1     NaN            NaN                    NaN          1
# 588      4     NaN            NaN                    NaN          0
# 590      3     NaN            NaN                    NaN          0
# 591      4     NaN            NaN                    NaN          4
# 592      1     NaN            NaN                    NaN          1
# 595      4     NaN            NaN                    NaN          3
# 596      0     NaN            NaN                    NaN          0
# 597      2     NaN            NaN                    NaN          2
# 598      3     NaN            NaN                    NaN          1
# 599      2     NaN            NaN                    NaN          1
# 600      2     NaN            NaN                    NaN          5
# 601      2     NaN            NaN                    NaN          1
# 602      2     NaN            NaN                    NaN          2
# 603      0     NaN            NaN                    NaN          1
# 604      2     NaN            NaN                    NaN          0
# 605      1     NaN            NaN                    NaN          0
# 606      2     NaN            NaN                    NaN          0
# 608      0     NaN            NaN                    NaN          0
# 609      4     NaN            NaN                    NaN          0
# 610      2     NaN            NaN                    NaN          1
#
# [351 rows x 14 columns]

# %%
toronto_mvenues['reasons_item_summary_1'].unique()
# Out:
# array([nan, 'Lots of people like this place'], dtype=object)

# %%
impCat = SimpleImputer(strategy='constant',fill_value='')
impCat.fit(toronto_mvenues[['reasons_item_summary_1','Venue Category']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value='', missing_values=nan,
#               strategy='constant', verbose=0)

# %%
x=impCat.transform(toronto_mvenues[['reasons_item_summary_1','Venue Category']])

# %%
x
# Out:
# array([['', 'Athletics & Sports'],
#        ['', 'Athletics & Sports'],
#        ['Lots of people like this place', 'Gym'],
#        ...,
#        ['', 'Hockey Arena'],
#        ['', 'Skating Rink'],
#        ['', 'Curling Ice']], dtype=object)

# %%
ordenc = OrdinalEncoder()

# %%
ordenc.fit(x)
ordcat_pd = pd.DataFrame(ordenc.transform(x),columns=['reasons_summary','encoded_venue_category'])

# %%
ordcat_pd['encoded_venue_category'].unique()
# Out:
# array([ 1., 17., 43., 18., 34.,  6., 26., 40., 16.,  3., 29., 36., 51.,
#        10., 46., 12.,  0.,  2.,  7., 19.,  4.,  9., 41.,  8., 33., 44.,
#         5., 25., 48., 13., 14., 47., 11., 32., 42., 39., 21., 37., 28.,
#        45., 23., 27., 15., 38., 30., 24., 49., 22., 50., 20., 31., 35.])

# %%
toronto_mvenues = toronto_mvenues.merge(ordcat_pd,left_index=True,right_index=True)

# %%
toronto_mvenues.loc[toronto_mvenues['Venue Category'] == 'Gym']
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 2                                    Hillcrest Village              43.803762
# 9                                      York Mills West              43.752758
# 11                                           Parkwoods              43.753259
# 12   Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
# 13                                          Davisville              43.704324
# 15                                   Maryvale, Wexford              43.750072
# 17                                              Woburn              43.770992
# 18                                    Davisville North              43.712751
# 20                                    Willowdale South              43.770120
# 23                                 Scarborough Village              43.744734
# 24                                           Agincourt              43.794200
# 25                                            Rosedale              43.679563
# 27                         Birch Cliff, Cliffside West              43.692657
# 31   Deer Park, Forest Hill SE, Rathnelly, South Hi...              43.686412
# 32                                   Hillcrest Village              43.803762
# 33                    Flemingdon Park, Don Mills South              43.725900
# 46                            Silver Hills, York Mills              43.757490
# 48                                Church and Wellesley              43.665860
# 54                             Newtonbrook, Willowdale              43.789053
# 57                            Silver Hills, York Mills              43.757490
# 59                                    Victoria Village              43.725882
# 63             Clarks Corners, Sullivan, Tam O'Shanter              43.781638
# 65                                     L'Amoreaux West              43.799525
# 66                     Clairlea, Golden Mile, Oakridge              43.711112
# 67                      The Beaches West, India Bazaar              43.668999
# 68                        The Danforth West, Riverdale              43.679557
# 69                                     York Mills West              43.752758
# 70                                     York Mills West              43.752758
# 71                                          Davisville              43.704324
# 73                   Bedford Park, Lawrence Manor East              43.733283
# ..                                                 ...                    ...
# 406                                    Willowdale West              43.782736
# 410  Agincourt North, L'Amoreaux East, Milliken, St...              43.815252
#
# 411                   North Thornhill Community Centre       43.832422
# 412         Markham YMCA Blvd. Rudy Bratty YMCA Centre       43.852389
# 414   GoodLife Fitness North York Dufferin and Steeles       43.785007
# 419                                       Snap Fitness       43.879923
# 421                         GoodLife Fitness Thornhill       43.829197
# 423      GoodLife Fitness Richmond Hill Hillcrest Mall       43.854895
# 425            GoodLife Fitness Markham Markville Mall       43.868439
# 428                            Steeles West Gymnastics       43.784672
# 430      GoodLife Fitness Vaughan Weston and Northview       43.790929
# 448                             Link Integrated Health       43.683174
# 454            North Toronto Memorial Community Centre       43.706098
# 455                                                Gym       43.713126
# 458                                         The Dugout       43.798969
# 478                                    Garment Factory       43.662932
# 483                        Corktown District Lofts Gym       43.655652
# 484                                         1 Cole Gym       43.659817
# 485                                         Gym @ Jazz       43.654293
# 486                                       Bay Club Gym       43.664406
# 498                                 Real Training Club       43.806445
# 536                                         Rogers Gym       43.670390
# 542           GoodLife Fitness Vaughan Major MacKenzie       43.846991
# 588                                       Panorama Gym       43.637953
# 589                               Oasis Fitness Centre       43.636806
# 590                             Neptune Fitness Centre       43.636686
# 591                                       Bang Fitness       43.647039
# 592                        The Matrix Gym (City Place)       43.642913
# 596             GoodLife Fitness Brampton Woodhill Gym       43.747506
# 599                                  Rogers Campus Gym       43.703808
#
#      Venue Longitude Venue Distance Venue Category  likes  rating  \
# 2         -79.344064           1900            Gym     34     7.5
# 9         -79.406346           1039            Gym     12     8.5
# 11        -79.341707           3029            Gym     10     7.4
# 12        -79.301411           1672            Gym     10     8.4
# 13        -79.387274            705            Gym     33     7.9
# 15        -79.313351           1655            Gym     39     6.9
# 17        -79.228533           1693            Gym     14     7.8
# 18        -79.395981            696            Gym     62     7.6
# 20        -79.411936            644            Gym     54     7.4
# 23        -79.213702           2084            Gym     28     7.8
# 24        -79.262510           1791            Gym      6     7.2
# 25        -79.389857           3262            Gym      7     7.3
# 27        -79.257952            883            Gym     15     7.1
# 31        -79.393596            576            Gym     32     7.1
# 32        -79.344093           1579            Gym     19     6.7
# 33        -79.331610           1003            Gym     15     6.5
# 46        -79.386617           1332            Gym     29     6.3
# 48        -79.384849            371            Gym     78     8.2
# 54        -79.416439           1147            Gym     21     6.2
# 57        -79.399036           5952            Gym     27     6.1
# 59        -79.327232           1087            Gym      3     NaN
# 63        -79.280695           1952            Gym      3     NaN
# 65        -79.319300             75            Gym      3     NaN
# 66        -79.284578            817            Gym      3     NaN
# 67        -79.319382            533            Gym     22     5.8
# 68        -79.345458            551            Gym     30     5.7
# 69        -79.406894            657            Gym      3     NaN
# 70        -79.409809            945            Gym      1     NaN
# 71        -79.387444            298            Gym      1     NaN
# 73        -79.394979           4356            Gym      3     NaN
# ..               ...            ...            ...    ...     ...
# 406       -79.461906           8068            Gym     37     8.6
# 410       -79.324064           4932            Gym      3     7.2
# 411       -79.475806           6152            Gym     11     7.5
# 412       -79.310798           4639            Gym     19     7.0
# 414       -79.471083           2298            Gym      7     6.0
# 419       -79.395947           8870            Gym      6     6.7
# 421       -79.427166           4713            Gym     31     6.2
# 423       -79.436198           7659            Gym     14     6.3
# 425       -79.287387           5925            Gym     24     5.9
# 428       -79.474500           2122            Gym      0     NaN
# 430       -79.545200           3797            Gym     13     5.8
# 448       -79.300078           3025            Gym      0     NaN
# 454       -79.404337           7134            Gym     16     7.7
# 455       -79.393537           6457            Gym      3     NaN
# 458       -79.530779           4230            Gym      3     NaN
# 478       -79.340321           9594            Gym      2     NaN
# 483       -79.358125           8553            Gym      0     NaN
# 484       -79.365751           8677            Gym      0     NaN
# 485       -79.375533           9675            Gym      4     NaN
# 486       -79.386620           9721            Gym      0     NaN
# 498       -79.550282           5722            Gym      1     NaN
# 536       -79.380010           9596            Gym      1     NaN
# 542       -79.552284           9828            Gym      0     6.8
# 588       -79.397996           1043            Gym      4     NaN
# 589       -79.405725           8448            Gym      8     6.6
# 590       -79.404664           8521            Gym      3     NaN
# 591       -79.404885           9034            Gym      4     NaN
# 592       -79.392462           9703            Gym      1     NaN
# 596       -79.699878           9007            Gym      0     NaN
# 599       -79.714913           9731            Gym      2     NaN
#
#      ratingSignals          reasons_item_summary_1  tip_count  \
# 2             46.0  Lots of people like this place         10
# 9             13.0                             NaN          1
# 11            12.0                             NaN          5
# 12            11.0                             NaN          1
# 13            48.0  Lots of people like this place          9
# 15            61.0  Lots of people like this place         17
# 17            20.0                             NaN          9
# 18            95.0  Lots of people like this place         24
# 20            85.0  Lots of people like this place         29
# 23            38.0                             NaN          9
# 24             8.0                             NaN          1
# 25            11.0                             NaN          2
# 27            24.0                             NaN          4
# 31            59.0  Lots of people like this place         23
# 32            34.0                             NaN         11
# 33            25.0                             NaN          7
# 46            52.0                             NaN         12
# 48           106.0  Lots of people like this place         14
# 54            38.0                             NaN         11
# 57            47.0                             NaN         15
# 59             NaN                             NaN          0
# 63             NaN                             NaN          0
# 65             NaN                             NaN          1
# 66             NaN                             NaN          1
# 67            42.0                             NaN         20
# 68            70.0                             NaN         27
# 69             NaN                             NaN          0
# 70             NaN                             NaN          1
# 71             NaN                             NaN          1
# 73             NaN                             NaN          0
# ..             ...                             ...        ...
# 406           46.0  Lots of people like this place          3
# 410            4.0                             NaN          1
# 411           19.0                             NaN          7
# 412           31.0                             NaN         11
# 414           13.0                             NaN          1
# 419            9.0                             NaN          3
# 421           57.0  Lots of people like this place         16
# 423           28.0                             NaN          9
# 425           47.0                             NaN         17
# 428            NaN                             NaN          0
# 430           23.0                             NaN          6
# 448            NaN                             NaN          0
# 454           23.0                             NaN          6
# 455            NaN                             NaN          2
# 458            NaN                             NaN          0
# 478            NaN                             NaN          1
# 483            NaN                             NaN          0
# 484            NaN                             NaN          2
# 485            NaN                             NaN          1
# 486            NaN                             NaN          1
# 498            NaN                             NaN          1
# 536            NaN                             NaN          3
# 542            1.0                             NaN          0
# 588            NaN                             NaN          0
# 589           13.0                             NaN          3
# 590            NaN                             NaN          0
# 591            NaN                             NaN          4
# 592            NaN                             NaN          1
# 596            NaN                             NaN          0
# 599            NaN                             NaN          1
#
#      reasons_summary  encoded_venue_category
# 2                1.0                    17.0
# 9                0.0                    17.0
# 11               0.0                    17.0
# 12               0.0                    17.0
# 13               1.0                    17.0
# 15               1.0                    17.0
# 17               0.0                    17.0
# 18               1.0                    17.0
# 20               1.0                    17.0
# 23               0.0                    17.0
# 24               0.0                    17.0
# 25               0.0                    17.0
# 27               0.0                    17.0
# 31               1.0                    17.0
# 32               0.0                    17.0
# 33               0.0                    17.0
# 46               0.0                    17.0
# 48               1.0                    17.0
# 54               0.0                    17.0
# 57               0.0                    17.0
# 59               0.0                    17.0
# 63               0.0                    17.0
# 65               0.0                    17.0
# 66               0.0                    17.0
# 67               0.0                    17.0
# 68               0.0                    17.0
# 69               0.0                    17.0
# 70               0.0                    17.0
# 71               0.0                    17.0
# 73               0.0                    17.0
# ..               ...                     ...
# 406              1.0                    17.0
# 410              0.0                    17.0
# 411              0.0                    17.0
# 412              0.0                    17.0
# 414              0.0                    17.0
# 419              0.0                    17.0
# 421              1.0                    17.0
# 423              0.0                    17.0
# 425              0.0                    17.0
# 428              0.0                    17.0
# 430              0.0                    17.0
# 448              0.0                    17.0
# 454              0.0                    17.0
# 455              0.0                    17.0
# 458              0.0                    17.0
# 478              0.0                    17.0
# 483              0.0                    17.0
# 484              0.0                    17.0
# 485              0.0                    17.0
# 486              0.0                    17.0
# 498              0.0                    17.0
# 536              0.0                    17.0
# 542              0.0                    17.0
# 588              0.0                    17.0
# 589              0.0                    17.0
# 590              0.0                    17.0
# 591              0.0                    17.0
# 592              0.0                    17.0
# 596              0.0                    17.0
# 599              0.0                    17.0
#
# [137 rows x 16 columns]

# %%
impQua = SimpleImputer(strategy='median',verbose=1)
impQua.fit(toronto_mvenues[['rating','ratingSignals']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=1)

# %%
x1=impQua.transform(toronto_mvenues[['rating','ratingSignals']])
transformed_ratings = pd.DataFrame(x1,columns=['imp_rating','imp_rating_signals'])

# %%
toronto_mvenues = toronto_mvenues.merge(transformed_ratings,left_index=True,right_index=True)

# %%
toronto_mvenues.head()
# Out:
#                         Neighborhood  Neighborhood Latitude  \
# 0     The Beaches West, India Bazaar              43.668999
# 1                           Rosedale              43.679563
# 2                  Hillcrest Village              43.803762
# 3  Bedford Park, Lawrence Manor East              43.733283
# 4                    Don Mills North              43.745906
#
#    Neighborhood Longitude                  Venue Id  \
# 0              -79.315572  50a01c82e4b0a0263fcfdcb9
# 1              -79.377529  4ba5156cf964a520b6da38e3
# 2              -79.363452  4bb4ccb486a8d13a7ce1de7f
# 3              -79.419750  4b0eb057f964a520b75923e3
# 4              -79.352188  4c18e819d4d9c9284e19f029
#
#                                               Venue  Venue Latitude  \
# 0                              Monarch Park Stadium       43.678144
# 1                          Toronto Lawn Tennis Club       43.680667
# 2  GoodLife Fitness North York Steeles and Woodbine       43.813541
# 3          Toronto Cricket Skating and Curling Club       43.739660
# 4                                        LA Fitness       43.747665
#
#    Venue Longitude Venue Distance        Venue Category  likes  rating  \
# 0       -79.324038           1225    Athletics & Sports     28     8.9
# 1       -79.388559            896    Athletics & Sports     11     8.6
# 2       -79.344064           1900                   Gym     34     7.5
# 3       -79.418732            714           Sports Club     15     7.3
# 4       -79.347077            455  Gym / Fitness Center     51     8.2
#
#    ratingSignals          reasons_item_summary_1  tip_count  reasons_summary  \
# 0           36.0                             NaN          7              0.0
# 1           11.0                             NaN          0              0.0
# 2           46.0  Lots of people like this place         10              1.0
# 3           22.0                             NaN          6              0.0
# 4           70.0  Lots of people like this place         20              1.0
#
#    encoded_venue_category  imp_rating  imp_rating_signals
# 0                     1.0         8.9                36.0
# 1                     1.0         8.6                11.0
# 2                    17.0         7.5                46.0
# 3                    43.0         7.3                22.0
# 4                    18.0         8.2                70.0

# %%
def sort_venue_by_distance(df):
    return df.sort_values(by=['Venue Distance'],ascending=True)

# %%
ocga = sort_venue_by_distance(unique_venues.loc[unique_venues['Venue']== 'Planet Fitness North Scarborough'])
ocga.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-305-9cdc7b310c30> in <module>
# ----> 1 ocga = sort_venue_by_distance(unique_venues.loc[unique_venues['Venue']== 'Planet Fitness North Scarborough'])
#       2 ocga.head()
#
# NameError: name 'unique_venues' is not defined

# %% [markdown]
# ###### Unique Venue Categories

# %%
toronto_venues.shape

# %% [markdown]
# Sports Club

# %%
toronto_venues['Venue Category'].unique()

# %%
unique_venues.shape

# %%
toronto_gym = toronto_venues

# %%
# create map of Downtown Toronto using latitude and longitude values
map_toronto_gym = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, venue, neighborhood in zip(toronto_mvenues['Venue Latitude'], toronto_mvenues['Venue Longitude'], toronto_mvenues['Venue'],toronto_mvenues['Neighborhood']):
    label = '{}, {}'.format(venue,neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='green').add_to(map_toronto_gym)  

map_toronto_gym

# %%
# create map of Downtown Toronto using latitude and longitude values
map_toronto_res = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, venue, neighborhood in zip(toronto_mvenues['Venue Latitude'], toronto_mvenues['Venue Longitude'], toronto_mvenues['Venue'],toronto_mvenues['Neighborhood']):
    label = '{}, {}'.format(venue,neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='orange').add_to(map_toronto_res)  
    
map_toronto_res

# %% [markdown]
# ###### Extracted Venues from each Neighbourhood

# %%
toronto_venues.head()

# %% [markdown]
# ###### Count of the Venues Receied for each Neighborhood.
# ###### Note: As highlighted above, API returned less venues for few neighbourhoods as it could only find those within the given radius

# %%
pd.DataFrame(toronto_venues.groupby('Neighborhood').count()['Venue'])

# %% [markdown]
# ###### Analyze based on Venue Category

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()

# %% [markdown]
# ###### Shape of the Dataframe after the onehot encoding

# %%
toronto_onehot.shape

# %% [markdown]
# ###### Group the Neighbourhoods with the corresponding encoded rows to see the most

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()

# %% [markdown]
# ###### Shape of the Grouped Dataframe

# %%
toronto_grouped.shape

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ###### Get & Print the Top 5 most common venues

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(10)

# %% [markdown]
# ###### Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
toronto_grouped_clustering.head()

# %% [markdown]
# ###### Add clustering labels

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!

# %% [markdown]
# ###### Create a map with clusted labels (produced in different colors)

# %%
toronto_merged = toronto_merged.dropna()
toronto_merged.head()

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)+7))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[np.int(cluster-1)]).add_to(map_clusters)
       
map_clusters

# %%
toronto_merged[]
